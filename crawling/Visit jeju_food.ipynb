# %%
import requests

# %% [markdown]
# ### 카테고리
# 관광지 : cate0000000002 <br>
# 쇼핑 : cate0000000003 <br>
# 숙박 : cate0000000004 <br>
# 음식 : cate0000000005 <br>

# %%
p = {
    '_siteId': 'jejuavj',
    'locale': 'kr',
    'device': 'pc',
    #카테고리
    'cate1cd': 'cate0000000005',
    'tag': '',
    'sorting': 'reviewcnt+desc,+title_kr+asc',
    'region1cd': '',
    'region2cd': '',
    'pageSize': 1642
}
h = {
    'Cookie': 'iceJWT=SDP+eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJBbm9ueW1vdXMiLCJhdWQiOiI4NzhhYzQ1Yi1mODA3LTRjNGMtOGU3My1kMjQ4YmQ4YmQzMGYiLCJqdGkiOiI4NzhhYzQ1Yi1mODA3LTRjNGMtOGU3My1kMjQ4YmQ4YmQzMGYiLCJpc3MiOiJJLU9OIiwiaWF0IjoxNjU3NzY0MDQ0LCJleHAiOjE2NTc4NzIwNDR9.SAgOU75Nisk-2-v4TFwkB-RSeeD9xCReVNIed_-usb8k6t9xzDrfb0FtFDQHC9eTXNrPg70z6RIwKTdaTdhW1g; iceRefreshJWT=SDP+eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJBbm9ueW1vdXMiLCJhdWQiOiI2OGRmY2Y5OC0xNzc3LTRkMDEtOTk3Zi1kMjRhZTM2Njk5YWMiLCJpc3MiOiJJLU9OIiwianRpIjoiYTdmZDUwY2UtN2M4Mi00YzE4LWFhYjktZGMwMDhmMjM4N2FjIiwiaWF0IjoxNjU3NzY0MDQ0LCJleHAiOjQxMDI0MTI0MDB9.i6nZyGwlomSxKqxXc8HihR-tiRAJtKPM2tCE5V5feqJeGKVs0vpO_jPP1mZ8h1P1fyniL7yMP-3k4BoOl0lEVg; _gcl_au=1.1.129734474.1657764048; _gid=GA1.2.460982230.1657764048; Hm_lvt_f6d5e380b023c5b1e946de764e07a2a2=1657764048; _fbp=fb.1.1657764048346.2028508788; _ga=GA1.2.695435354.1657764048; _gat_gtag_UA_74784502_6=1; Hm_lpvt_f6d5e380b023c5b1e946de764e07a2a2=1657764364; _ga_WR7WEFWP2T=GS1.1.1657764048.1.1.1657764373.0'
}

# %%
# pagelist = []
# #검색 카테고리 max페이지 수
# maxPG = 110
# for i in range(1,maxPG+1):
#     res = requests.get(f'https://api.visitjeju.net/api/contents/list?page={i}&', params=p, headers=h)
#     pagelist.append(res.json())

# %%
res = requests.get(f'https://api.visitjeju.net/api/contents/list?page=1&', params=p, headers=h)
jeju_food = res.json()

# %%
len(jeju_food['items'])
# Out:
# 1642

# %%
jeju_food['items'][1641]['title']
# Out:
# '소라의성'

# %%
jeju_food['items'][0]['contentsid']
# Out:
# 'CNTS_200000000009113'

# %%
jeju_food['items'][0]['contentscd']['label']
# Out:
# '음식점'

# %%
jeju_food['items'][0]['catemappList'][0]['cate2cd']['label']
# Out:
# '한식'

# %%
jeju_food['items'][0]
# Out:
# {'alltag': '추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,조기구이,정식,식당',
#  'contentsid': 'CNTS_200000000009113',
#  'contentscd': {'value': 'c4', 'label': '음식점', 'refId': 'contentscd>c4'},
#  'title': '황금섬숯불갈비',
#  'region1cd': {'value': 'region3',
#   'label': '섬 속의 섬',
#   'refId': 'region>region3'},
#  'region2cd': {'value': '32', 'label': '추차도', 'refId': 'region3>32'},
#  'address': '제주특별자치도 제주시 추자면 대서리 140-6',
#  'roadaddress': '제주특별자치도 제주시 추자면 추자로 36',
#  'tag': '추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,조기구이,정식,식당',
#  'introduction': '추자에서 즐기는 제주산 돼지고기',
#  'readcnt': 376,
#  'likecnt': 0,
#  'reviewcnt': 0,
#  'markcnt': 2,
#  'snssharecnt': 0,
#  'schedulecnt': 0,
#  'visitcnt': 0,
#  'evelpt': 0,
#  'latitude': 33.9636778,
#  'longitude': 126.2957655,
#  'postcode': None,
#  'phoneno': '064-742-0478',
#  'sbst': '65명 수용가능한 단체가능석에 육고기 요리와 생선요리를 같이 파는 음식점',
#  'created': '20190820152943',
#  'changed': '20220708114819',
#  'catemappList': [{'seq': 30792,
#    'contentsid': {'value': 'CNTS_200000000009113',
#     'label': '황금섬숯불갈비',
#     'refId': 'CNTS_200000000009113'},
#    'cate1cd': {'value': 'cate0000000005',
#     'label': '음식점',
#     'refId': 'contscate>cate0000000005'},
#    'cate2cd': {'value': 'cate0000001266',
#     'label': '한식',
#     'refId': 'cate0000000005>cate0000001266'},
#    'cate3cd': {'value': 'cate0000001310',
#     'label': '한식',
#     'refId': 'cate0000001266>cate0000001310'},
#    'created': '20220506170346'}],
#  'festivalcontents': None,
#  'repPhoto': {'descseo': '황금섬숯불갈비',
#   'photoid': {'photoid': 2019022560259,
#    'imgpath': 'https://api.cdn.visitjeju.net/photomng/imgpath/201908/20/e60fda5b-d85e-46bd-ad95-9e5eaa0bda8a.JPG',
#    'thumbnailpath': 'https://api.cdn.visitjeju.net/photomng/thumbnailpath/201908/20/d10c9bac-ec7e-4aa2-ac2b-a818539f1416.JPG'}},
#  'PHOTOSHARECOUNT': 0,
#  'reservelink': None}

# %%
jeju_food['items'][0]['repPhoto']['photoid']['imgpath']
# Out:
# 'https://api.cdn.visitjeju.net/photomng/imgpath/201908/20/e60fda5b-d85e-46bd-ad95-9e5eaa0bda8a.JPG'

# %% [markdown]
# title, address, roadaddress, tag, readcnt, likecnt, reviewcnt, markcnt, snssharecnt, schedulecnt, visitcnt, latitude, longitude, phoneno, sbst,

# %%
# for i in range(len(jeju_food['items'])):
#     title = jeju_food['items'][i]['title']
#     address = jeju_food['items'][i]['address']
#     roadaddress = jeju_food['items'][i]['roadaddress']
#     tag = jeju_food['items'][i]['tag']
#     readcnt = jeju_food['items'][i]['readcnt']
#     likecnt = jeju_food['items'][i]['likecnt']
#     reviewcnt = jeju_food['items'][i]['reviewcnt']
#     markcnt = jeju_food['items'][i]['markcnt']
#     snssharecnt = jeju_food['items'][i]['snssharecnt']
#     schedulecnt = jeju_food['items'][i]['schedulecnt']
#     visitcnt = jeju_food['items'][i]['visitcnt']
#     latitude = jeju_food['items'][i]['latitude']
#     longitude = jeju_food['items'][i]['longitude']
#     phoneno = jeju_food['items'][i]['phoneno']
#     sbst = jeju_food['items'][i]['sbst']
#     contentsid = jeju_food['items'][i]['contentsid']
#     jeju_food['items'][0]['contentscd']['label'] # 음식점
#     jeju_food['items'][i]['catemappList'][0]['cate2cd']['label'] # 한식
#     imgpath = jeju_food['items'][i]['repPhoto']['photoid']['imgpath']
# Out:
# 황금섬숯불갈비
# 일품순두부삼화점
# 해적선
# 제주콩순옥
# 자연으로
# 돈풍년
# 미원
# 뉴남원분식
# 제주정
# 허브올레
# 행복맛집
# 진미네식당
# 제주맛촌본점
# 해성도뚜리
# 현기네식당
# 운해횟집
# 생이소리
# 이가
# 육갑봉
# 밤낮가온
# 바위소리
# 올레산야초
# 원당골
# 우뭇개일번지
# 바온탑
# 보말과풍경
# 현경식당
# 금뽕똘향토음식점
# 바다잔치
# 세자매식당
# 정순화손두부
# 명문사거리식당
# 마중물삼계탕
# 만부정
# 홍도니
# 다미회
# 이런날N
# 꽃밭에서
# 보틀앤볼
# 꼬꼬닭한마리
# 무진장식당
# 오르막가든
# 독도참치
# 1080칼국수
# 제니의 정원
# 대포횟집
# 금강민물장어
# 홍요깃거리카페
# 일출왕뚝배기
# 시니어손맛 아리랑
# 신성할망식당
# 수카사
# 듀포레
# 만배성
# 제주돔베막국수
# 길벗식당
# 와르다 레스토랑
# 청파식당횟집
# 만복흑돼지
# 순풍해장국
# 두리호집
# 할매추어탕
# 중화요리 사해방
# 착한집
# 호도제과
# 함덕쉼팡
# 고래라면 신화역사점
# 신동성식당
# 방듸
# 메로식당
# 천보식당
# 해월향
# 동동차이나
# 다미진
# 황금어장(제주시)
# 팔도수산식당
# 깜돈 흑돼지
# 메종드쁘티푸르
# 돈이랑 서귀포점
# 모메존
# 도다모
# 쉬는팡가든
# 노을언덕
# 선미식당
# 스시호시카이
# 누리해장국
# 우도자연
# 돈마구이해장국(연동점)
# 제주올레횟집
# 호돌이식당
# 우도아름다운소풍
# 탑동산호전복
# 부두식당 (모슬포)
# 나원회포차
# 꽁순이네
# 와토커피
# 천리식당
# 데미안
# 덕승식당(구관)
# 돌집식당
# 어반르토아
# 쇠소깍모꼬지
# 광평도새기촌 본점
# 성산흑돼지두루치기
# 카페 사우다드
# 대박국수
# 섭지코지 해녀밥상
# 일도 국수
# 리듬
# 옥돔식당
# 대우정
# 피노키오
# 국수장터
# 카페희상
# 황토기와집
# 서귀포흑돈
# 하르방밀면(운동장점)
# 마린보이횟집
# 간이옥돔역
# 철가방을든해녀
# 어부피자
# 종종캐주얼다이닝
# 흑돼지구이집 하영
# 산방산초가집
# 얌얌돈까스
# 지붕위제주바다
# 어우늘
# 카페앤드효은양갱
# 국시트멍
# 버터모닝
# 아이스크림연구소(우도점)
# 포도원흑돼지
# 그러므로
# 숨비나리카페
# 등경돌식당
# 신촌덕인당
# 카페태희
# 성산해오름식당
# 달콤한휴식
# 면뽑는선생 만두빚는아내
# 제주한면가
# 국수냐 국밥이냐
# 달마야해물탕
# 화진전복
# 삼무국수
# 남또리
# 덤장
# 바굥식당
# 이드레국수
# ROAD129(로드129)
# 우도몬딱
# 제주해물밥
# 망고홀릭 제주본점
# 교래흑돼지
# 비원
# 골막식당
# 포도호텔레스토랑
# 더화원
# 곱들락
# 메콩스카이
# 생돈우리
# 소곱에
# 비바리짬뽕
# 타코마씸
# 피시야 카페
# 한치앞도모를바다
# 청운식당
# 연정식당
# 다래향
# 하얀산호식당
# 바다의집
# 전설의마녀
# 제스피
# 현옥식당
# 마마롱(애월)
# 미송식탁
# 바다를본돼지(판포점)
# 동도원
# 삼일식당
# 회양과 국수군
# 우드스탁
# 도토리키친
# 연이네
# kim여사의밥상
# 강해일횟집
# 탭하우스더코너
# 돈향기
# 달사막
# 보영반점
# 올래회어촌
# 곰막
# 도희네칼국수
# 예지원
# 하우스레서피
# 비밀의숲 카페
# 순천미향
# 대광장식당
# 카페숑
# 그림상회화덕피자
# 바다는안보여요
# 떡하니
# 73st
# 돼지촌
# 옛날동문시장칼국수
# 중문덤장
# 이가전복
# 복단지식당
# 옛날옛적
# 낭쿰낭쿰
# 도두반점
# 황금무지개
# 영림흑돼지가든
# 치저스
# 길림성
# 동해루
# 신등대수산회센타
# 코너스윗
# 보라네
# 촵촵
# 추가네
# 베지그랑
# 로드3.7 (road3.7)
# 추자북경
# 미나리(제주시)
# 슬로우카페
# 이맛
# 엠츄로
# 만선바다
# 라 아바나
# 유끼네
# 제주돌담촌
# 웅담식당
# 보노리미니
# 봉골레밥상
# 봉이네식당
# 오라오거리정식
# 한밭식당
# 느지리식식당
# 해뜰
# 앞돈지
# 모리노코에
# 카페3535.1
# 호끌락다락
# 육값하네식육가든
# 한양식당
# 참이쁜돼지
# 가온해
# 피노
# 스테이크 하우스
# 세컨드밀
# 라쁠라주
# 나주닭집
# 노리터스낵
# 청정고을식당
# 지꺼진밥상
# 일오삼가든
# 털보네 고양이
# 마마식당
# 친구네 분식
# 팜스테이블
# 꽃자리
# 일탈흑돼지
# 순심이네한라봉돼지갈비
# 웃뜨르우리돼지
# 커피파인더
# 삼바리회센타
# 누룽지식당
# 지상에 별두개
# 동북왕
# 그릴데미그라스
# 이찌마루
# 부엌인세화
# 묘한상점 묘한카페
# 풍미독서
# 올레삼다정
# 달리북카페
# 수다브런치카페
# 바농
# 앙뚜아네트 용담점
# 한라네 김밥
# 해변가든(켄싱턴리조트)
# 용담생국수
# 신스버거
# 잔디가미
# 마마무말가든
# 오르미
# 오누이밥상
# 차롱 해모루
# 덕승식당(신관)
# 진부령 황태해장국
# 갯마을
# 마라도별장식당
# 심봉사눈뜬톳해물짜장짬뽕
# 솜반내풍경
# 바닐라파레트
# 달빛머금은카페
# 탭룸3029
# 플로렌스
# 뽀요요 카페
# 올레실내포장마차
# 꽃담팥집카페
# 달페이지
# 고객식당
# 경성통닭
# 춘미향 식당
# 산호반점
# 씨리얼
# 우리두리식당
# 까미노
# 오캄
# 갤러리 라운지
# 세이슌 칠성로점
# 하늘채가든
# 책다방
# 한량2010
# 제주분식
# 커피로카
# 환상의짜장
# 블루사이공
# 모노클제주
# 뚱순이 꼬마김밥
# 솔향
# 산책하우스
# 어머니빵집
# 우리동네숯불갈비
# 다이노바이트 샌드위치
# 에이스쌀국수
# 앙카페
# 재게재게옵서 카페
# 유메야마
# 미복빈대떡
# 감산우리가든
# 키친그듸
# 뚜르
# 동우통닭
# BBQ치킨 추자점
# 맛있는집
# 돌섬
# 지오아라
# 서문뒷고기
# 가산토방 식당
# 베이비카페 어놀
# 천지연해물전복뚝배기
# 마음카페
# 미루네
# 미소짓는 흑도야지
# 알라스카인제주 용담점
# 마라톤식당
# 써니하우스 커피&핫도그
# 딕시
# 숲속의작은집
# 후년하우스
# 바캉스샤브샤브
# 명도암수다뜰
# 산내들식당
# 하나로국밥
# 금보가든
# 파리바게트 도남점
# 종이비행기
# 유기농커피 카페다
# 어피니티
# 파도소리해녀촌
# 쇼디치카페
# 탐라가든
# 돌코롬허니
# 달리다방
# 루스트플레이스 삼화점
# 우도향
# 준반점
# 뵈뵈
# 이게밥도둑
# 아꼬떼카페
# 추억의 집
# 달에
# 지중해그릴
# 라스또르따스
# 브릭스 제주
# 맛나리
# 애월바베
# 까망돼지
# 순희뽀글이
# 귤따고 레드향갈고
# 하비마카롱
# 유심이감성찜닭
# 팝업 플라자
# 사수만수횟집
# 알마니
# 보말고을
# 돈가
# 문쏘
# 제주본초협동조합
# 시즌박스
# 세러데이아일랜드
# 우도동식이
# 중문신라원
# 제주복돈
# 중문수원음식점
# 원항아리칼국수보쌈
# 원더먼트제주
# 해녀3대할망네
# 겐짱야
# 루스트플레이스 아이파크점
# 가야아구찜
# 로치아 커피로스터스
# 컴홈
# 커먼브릭
# 성광식당
# 백번가든
# 마레벤또
# 네이쳐캔바스
# 안트레
# 우정회센타
# 보말이야기
# 옛정의골 식당
# 어애랑
# 토담골
# 바다를 본 돼지(서귀포점)
# 바라나시 책골목
# 삼수정
# 달리맨
# 제주광어씨푸드레스토랑 표선점
# 두가시가든
# 돈돼지흑돼지
# 중문랜드프리미엄뷔페
# 봉쉡망고
# 아싸횟집
# 대기정
# 소녀방앗간
# 유나카페
# 뿔소라몽땅정식
# 한라성
# 봉주르마담
# 온미(溫米)
# 함덕찜
# 루스트플레이스 외도점
# 망고홀릭 법환점
# 밀리우
# 카페갤러리
# 조가네갑오징어 신제주점
# 루스트플레이스 베라체점
# 카페루나
# 라포레사려니
# 카페선흘
# 넘버 138
# 법환어촌계횟집
# 제주와이너리
# 노조미
# 차귀놀
# 갯것이식당
# 생원전복
# 너는파라다이스길리
# 멘도롱 cafe
# 차이나 하우스
# 오복떡집
# 더로맨틱
# 바람이풀에그림그린날
# 잇칸시타
# 꽃향유
# 서울떡볶이
# 미인계 카페
# 모퉁이스낵
# 킨포크
# 수모루국수
# 삼원정
# 하빌리스
# 토향
# 루스트플레이스 칠성로점
# 신 해바라기분식
# 선흘방주할매식당
# Jeju in aA카페
# 면사무소
# 쿠싱 샌드위치
# 에이팩토리 커피앤북스
# 하우스142
# 탐라흑돼지
# 고마워토토 아뜰리에
# 오솔길
# 구닮카페(구름을닮다)
# 탐라 뚝배기
# 우림일식
# 루스트플레이스 아라점
# 고로케야
# 이조은식당
# 부지깽이
# 해와달그리고섬
# 수제홍과일모찌
# 삼대해녀의집
# 돌코롬봉봉
# 다람쥐 식탁
# 두루두루
# 마농
# 다래향2호점
# 박장군
# 사방팔방
# 토이다방
# 곽지BAR다
# 코코분식
# 쉐프 이야기
# 마쇼
# 리솔라 무인카페
# 인더오조
# 정봉자커피 봉개점
# 봉봉커피
# 오로라식당
# 텐피자
# 레드썬셋
# 어멍
# 말이
# 서민흑돼지
# 제니스브레드
# 카페헤밍웨이
# 유스커피
# 아뜰리에 제주명월
# 저팔계깡통연탄구이
# 춘희
# 만민식당
# 모래비카페
# 진대감12제주
# 레터스 투 시리얼
# 몬떼마레
# 벨로인카페
# 오동여식당
# 행복한시저네
# 오르다키친
# 블랙포엠
# 제원분식
# 모메든식당
# 비양도 올레카페
# 마실디
# 경미네집(경미휴게소)
# 소울키친
# 송악산 엉클스 화덕 피자
# 어사촌도야지
# 중문자연산횟집
# 추자도중앙식당
# 해적카페
# 불만나
# 순정문어
# 햇살가득돌담집
# 하와이새우트럭
# 마초그릴
# 모실래기해녀해물촌
# 산호풍경
# 월리월리
# 바당지기
# 우무깨식당
# 저스트쉬림프
# 마라도에서온자장면집
# 협재삼춘네횟집
# 창천삼거리식당
# 스시우다
# 안거리밖거리
# 중문솥뚜껑
# 어전횟집
# 산호사 해녀의집
# 대굴대굴구이
# 스테이위드커피
# 봉평메밀가
# 제주이야기
# 옛고을갈비
# 월드컵흑돼지
# 홍돈깡통연탄구이
# 산포식당
# 빌라드아토
# 미영이네식당
# 아뜰리에안
# 월척수산
# 물질식육식당
# 보엠
# 아웃도어키친
# 또또시
# 오일등식당
# 망고레이
# 바람개비
# 아모르키친
# 이어도전복해물전문점
# 바다어사또
# 한라산빵 1950
# 어멍횟집
# 엉클망고
# 살랑살랑샤브샤브
# 사형제횟집
# 승범이네집
# 탐라면
# 연미정
# 띠띠빵빵
# 복여네왕돈가스
# 신옛촌
# 카페소금
# 청도해물탕
# 한마음돈가돈
# 커피가게쉬고가게
# 연우네
# 중문대들보
# 칠사돈
# 시골길
# 아일랜드팩토리 풍류
# 맛좋은디
# 사려니숲길화덕피자
# 어머니몸국
# 마므레
# 한라통닭
# 에릭스에스프레소 카페
# 우도돼지네 땅콩만두
# 미나리식당
# 제주틈
# 한우네백년해장국
# 카페백퍼
# 마더카페
# 레드브라운
# 만세국수 삼성혈점
# 섯동네해녀의집
# 천하대장군
# 용두암 바당회국수
# 빅토리아
# 로맨틱하드보일드
# 라지마할 RAJMAHAL
# 마라도해녀촌짜장
# 엉덩물
# 제주 강남해물탕
# 내담
# 젠하이드어웨이
# 버거307
# 파리바게트 제스코본점
# 소라횟집
# 탐라화덕피자
# 카페하물
# 섶섬지기
# 초승달지대
# 샤라의정원
# 신짜장
# 고가네
# 제주 핫팟
# 아랑
# 맥파이 브루어리
# 착한마녀김밥
# 신설오름
# 돌미롱
# 한성오메기떡
# 귤하르방 동문시장점
# 대춘해장국 노형점
# 맥파이 블루버드
# 바다가는길
# 모이세해장국 노형점
# 돈사촌
# 맨도롱해장국
# 으뜨미
# 펠릭스
# 제주스
# 숙성도
# 쉬멍가
# 일도국수
# 제주판타스틱버거
# 서서방 숯불닭갈비
# 순희뽀글이정식
# 천금반점
# 달인수산
# 황우정
# 친절한비자씨
# 야시장맛통령
# 죽성고을
# 베이커리 포그
# 예산가마솥장수촌설렁탕
# 빵귿
# 동막골
# 왓섬
# 포스트커피
# 화북빵굽는사람들
# 바우네나주곰탕 삼화점
# 제주인짬뽕
# 메종드베니
# 국제부두토산품스낵
# 안전식당
# 델문도로스터스
# 봉자살롱
# 루스트플레이스 구남점
# 모닥치기
# 고씨네천지국수
# 카페록록
# 그계절
# 윈드스톤
# 월정리LOWA
# 풍림다방 송당점
# 싱싱잇
# 한라축산정육식당
# 레이지펌프
# 큐티파이 카페
# 너와의 첫여행
# 하르방짬뽕
# 니모메빈티지라운지
# 순두부엔짬뽕
# 나라돈까스
# 커피스케치
# 서유기마라탕
# 소소당양갱
# 바삭돈까스 신서귀포점
# 난드르바당
# M1971엠브릿지
# 블랑제리
# 스피닝울프
# 미스틱3도
# 황금손가락 노형점
# 제주순풍해장국노형점
# 패밀리만두
# 김서방재첩해장국
# 룡천왕갈비탕
# 대독장(제주본점)
# 칠돈가 별관
# 바로족발보쌈 별관
# 마라도횟집
# 섭지코지로
# 아라파파 북촌점
# 라토커피
# 다니쉬
# 만세국수 본점
# 섬타르
# 동백별장
# 리치망고 도두해안로점
# 다가미 애월점
# 스시도모다찌 제주점
# 탑해장국앤돈가스
# 매일통닭
# 제주오일장반점 제주신화월드점
# 스콘가게 끌림
# 조은빵
# 바보라면
# 김밥명가 서귀포점
# 식과함께
# 에프터글로우
# 김명자굴국밥(성산점)
# 세이슌 시청점
# 제주기사정식뷔페
# 진주식당
# 카페인우도
# 뱅인타코
# 돔베돈
# 아리(あり)
# 잔물결
# 옥만이네
# 메종드쁘티푸르 노형점
# 통돌이돈통가
# 은희네해장국 외도점
# 김명자굴국밥 화북점
# 심바카레
# 명태명가
# 대춘해장국
# 제주와함께라면
# 무거버거
# 훈남횟집
# 에오마르
# 우도짜장맨
# 온오프
# 장수해장국
# 미풍해장국 서귀포직영점
# 오또도넛
# 뷰스트
# 해조네
# 휴일로
# 해주소반
# 땡큐베리
# 본디국수
# 그리트커피
# 산굼부리카페
# 연동둘둘김밥
# 협재온다정
# 제주신화월드 윤경양식당
# 비자림국수집
# 진양해장국
# 털보네 장원랜드
# 마모루
# 한림웅담
# 부원뚝배기
# 하르비커피
# 벨라지다
# 바다제비
# 웰덤대게고로케 올레시장점
# 뵤뵤
# 할머니떡집방앗간
# 비테비테
# 회춘
# 바로족발보쌈 본점
# 제주에가면
# 제니의정원
# 카페더라이트
# 프로젝트 064
# 제주축협한우플라자
# 성화정
# 삼일해장국
# 제레미
# 바램목장&카페
# 못잊어 감자탕
# 촐리케이크
# 함덕마당
# 애월 우니담
# 수애기베이커리
# 르토아 베이스먼트
# 다정이네
# 우리회수산
# 일품순두부함덕점
# 라온베이커리 남녕점
# 명품전통육개장 본점
# 카페유주
# 24시뼈다귀탕동홍점
# 만강촌옛날칼국수
# 청담집
# 용꽈배기
# 태산봉해장국
# 오백장군과 까마귀
# 대춘해장국 시청점
# 카페 라라라
# 소소희
# 중문정
# 외도339
# 제갈양 제주협재점
# 문치비 본점
# 큰돈가 중문점
# 효섬마을초가집
# 다올김밥분식
# 두루김밥
# 동이트는집
# 파라토도스
# 제주관덕정분식
# 골목카페옥수
# 춘심이네 본점
# 제주약수터 올레시장점
# 랜딩 라운지
# 빵하우스
# 로스트&헤븐
# 제주머슴네
# 참솔식당
# 다다익고 정육식당
# 안녕협재씨
# 인디안썸머애월
# 카페한라산
# 협재신국수
# 중국집마씸
# 미쿠니
# 미미국수
# 형돈
# 가리본가 본점
# 월정해녀식당
# 금능샌드
# 만월당
# 올디벗구디
# 서광보말칼국수
# 나눔김밥
# 제주통큰장어
# 라운지엑스 애월점
# 로빙화
# 신화테라스
# 앙끄레국수
# 컬쳐드 아라점
# 이스트포레스트
# 제주설심당 본점
# 아이갓에브리씽
# 애월은혜전복
# 황제궁
# 곤밥2
# 장인의집
# 성산일출봉 해송
# 해왓
# 꽃가람
# 성산 호랑호랑
# 오현불백
# 솔동산고기국수
# 보룡제과
# 칠돈가 표선직영점
# 커피가게&쉬고가게
# 옵써빵집
# 해비치불턱
# 채훈이네해장국
# 애월그때그집 본점
# 콜로세움
# 벙커하우스
# 60빈스
# 카페탠저린
# 한담팥빵
# 산지해장국
# 제주약수터 본점
# 그때그집 함덕
# 큰돈가 본점
# 썬셋클리프
# 별오름 노형점
# 순옥이네명가 함덕점
# 모뉴에트
# 서광리123
# 애월빵공장앤카페
# 노을코지
# 일품순두부탑동점
# 제주시새우리 제주점
# 썸의시작
# 쉐프의스시이야기
# 클로리스 제주성산점
# 보레드베이커스
# 게판5분전
# 카페아오오
# 커피템플
# 절물자연휴양림휴게소
# 일품순두부 하귀점
# 흑돼지돈까스 뷔페 밀라네사
# 청춘부부
# 보말보말
# 카페이시도르
# 솔트스톤
# 백리향
# 뚱보아저씨
# 지미스천연아이스크림
# 돈파스타정원
# 크래커스 한경점
# 오라디오라
# 꼬신김밥 본점
# 풀베개
# 한옥집
# 인카페온더비치
# 중문해물라면오빠네
# 고요새
# 돌카롱 사려니숲길점
# 리치망고 신화월드점
# 해녀김밥 본점
# 어진이네 횟집
# 해녀세자매
# 카페루시아
# 만선식당
# 산도롱맨도롱
# 타이웍
# 봉you
# 중식당 청
# 티나케이크
# 물꼬해녀의집
# 중문수두리보말칼국수
# 그리운바다성산포
# 성산 고등어쌈밥 김치찜
# 문화통닭
# 카페나모나모
# 칠돈가 중문점
# 피제리아3657
# 카페 보름왓
# 고서방해물탕
# 진돼지
# 더 콘테나
# 모모제이
# 임순이네
# 도남오거리 도남점
# 제주다음
# 놀놀카페
# 황금어장
# 청년다방 이도점
# 가파도해물짜장짬뽕
# 어림향
# 도렐
# 짱아저씨
# 비포크비스트로
# 카페 도두
# 서우봉가든
# 달아래팥
# 고불락
# 혜자분식
# 호랑이해장국
# 델리지아레스토랑
# 섬채
# 그초록
# 제주명가두루치기
# 샤오츠
# 마두천손칼국수
# 대수길다방
# S BAR
# 인디언키친
# 돈사촌 외도점
# 담다
# 협재칼국수
# 윤옥
# 체면
# 아라파파 a la papa
# 미드나잇 제주
# 토끼문
# 제주흑돈세상수라간
# 카페오름
# 그러므로part2
# 어부와농부
# 그대와함께라면
# 짬뽕에취한날
# 일품순두부 연동점
# 스모크하우스인구억
# 제주오성
# 카페피크닉(르피크닉)
# 순이네해장국
# 중문어촌계해녀의집
# 연동길
# 대관원
# 한라축산정육식당 노형점
# 허니문하우스
# 수복강녕
# 서귀포갈비
# 다해복국
# 카페제주동네
# 태광식당
# 만세국수
# 무뚱 식도락 식당
# 와랑와랑카페
# 24시얼큰시원생고기김치찌개노형점
# 이어도식당
# 백사장횟집(백사장회센터)
# 삼보식당
# 파파야 수제버거
# 해금강횟집
# 영춘식당
# 서귀피안베이커리
# 덕인당보리빵 제주점
# 삼대국수회관
# 순덕이네해산물장터
# 평대랑 그네랑
# 명품한라봉아이스크림
# 앞뱅디식당
# 동해미락
# 대원가
# 빨간집
# 제갈양
# 난드르깡통구이
# 허벅식당
# 코코티에
# 비양도식당
# 산방산에 옛촌
# 카페 글렌코
# 가파도 용궁정식
# 리치망고 협재점
# 다미안
# 남해횟집
# 제주올레냉면 제주노형점
# 해녀식당(동복리)
# 촌촌해녀촌
# jival 지발
# 솔리브레
# 월정리갈비밥
# 더건강한빵
# 안다미로
# 올레수산회센터
# 올댓제주
# 다육이풍경
# 오는정김밥
# 바람벽에흰당나귀
# 참맛나김밥
# 게우지코지 카페
# 사계바다
# 무인카페 산책
# 잠녀해녀촌
# 동글이흑돼지바베큐
# 과수원집
# 탕궁훠궈
# 인쌩맥주 노형오거리점
# 삼성혈해물탕
# 우도이야기
# 볕이드는곳벧디
# 허파곶자왈화덕피자
# 엠 라운지 M Lounge
# 카페 베트로(CAFÉ VETRO)
# 성산 어멍횟집
# 민경이네어등포해녀촌
# 용두암해녀촌
# 제주토속
# 푸주옥도남점
# 미엘드세화
# 초밥군커피씨
# 제스토리
# 제주베이통갈치구이
# 명리동식당
# 고고리식당
# 그루브
# 김이박
# 본가
# 삼다도횟집
# 영주말가든
# 더비치하우스
# 문동일셰프녹차고을
# 유람위드북스
# 마로니에 미니골프카페
# 만조이천쌀밥
# 시흥해녀의집
# 제주선 더블랙
# 야자수 식당
# 더꽃돈
# 화로향
# 24시전주명가콩나물국밥
# 쇠소깍오메기식당
# 모앙
# 늘봄흑돼지
# 세평맛집
# 마농오메기통닭마농문어통닭
# 레이지박스
# 삼대국수회관 신제주점
# 돈이랑
# 아찌국밥
# 은희네해장국(일도점)
# 하노이안브라더스
# 덕성원
# 오쿠다 이도점
# 메밀꽃차롱
# 춘심이네 2호점
# 낭뜰에쉼팡
# 남양수산
# 호박다방
# 아서원
# 섭지해녀의집
# 돌하르방 뚝배기
# 유리네
# 남경미락
# 톰톰카레
# 카페동백
# 미번베트남쌀국수
# 이춘옥원조고등어쌈밥
# 카페리(CAFERI)
# 청호식당
# 둥지식당
# 신산리마을카페
# 토끼와거북이
# 해마루
# 안녕육지사람
# 김지순의 낭푼밥상
# 거멍국수
# 달자카페
# 청춘테이블
# 카페 깡
# 리치망고우도점
# 더 코브
# 평대성게국수
# 창훈이네
# 최고집
# 피자굽는돌하르방
# 고집돌우럭(제주공항점)
# 치치퐁
# 신의한모
# 자리돔횟집
# 디 아일렛 라운지
# 기억나는집
# 가든이다
# 이돈갓시청점
# 한라식당
# 가시식당
# 서광춘희
# 섭지향
# 흑한우명품관
# 올레7돈 (올레칠돈)
# 쪼끌락
# 코코마마
# 독개물항
# 레드팬더
# 주상절리회국수
# 대성아귀찜
# 부촌홍어
# 카페쉼표
# 바다위에코끼리
# 백양닭집
# 교래손칼국수
# 모디카
# 카페스노우빈
# 우도해녀식당
# 성읍칠십리식당
# 올랭이와물꾸럭
# 흑염소마루
# 김녕제주흑돼지정육점식당
# 전망대횟집
# 차이나마씸
# 2093하우스
# 뽈살집
# 홍삼흑돼지
# 마돈
# 광원
# 한성식당
# 내가 찾은 맛고을
# 몽생이
# 동양식당
# 우수미회센타
# 커피주의보
# 오늘은 녹차한잔&쇼핑
# 국수와냉면
# 앙뚜아네트 삼다수마을점
# 긍정동커피
# 하늘창고
# 늘예솔
# 카페세렌디
# 쓰쓰카페
# 거기제주
# 함덕카페h
# 제주돌창고
# 차귀도놀빛바다
# 머문카페
# 여행가게
# 하원가흑돼지
# 애월 고깃간
# 에피소드
# 카페이피엘
# 고사리식당
# 제주의봄
# 탐라반상
# 수월봉 가마솥순대국
# 제주한치빵 우도점
# 애월리안
# 코코리파이프
# 봉플라봉뱅
# 돈채
# 시스터필드
# 카카듀
# 뚱보조개
# 제주담
# 색달식당
# 석촌식당
# 비올레제주
# 금보
# 창흥식당
# 대향연탄구이
# 우드노트
# 컴플리트커피
# 시스베이글
# 곽지식당
# 술도가제주바당
# 도가촌
# 파시랑
# 방모루
# 헬로우우도
# 소라네집
# 브와두스
# 용이식당
# 구면카페
# 카페 8
# 서홍정원
# 울트라마린
# 먹쿠슬낭여행자카페
# 문어빵굽는 문빵9 서귀포올레시장
# 24시 뼈다귀탕 제주점
# 까떼커피
# 이익새양과점
# 만덕식당
# 차마실
# 레이식당
# 메리앤폴
# 망고봉봉
# 달래식당
# 복댕이
# 별난카페
# 모리노아루요
# 수망일기
# 우정횟집
# 픽스커피
# 루스트플레이스 서귀포점
# 위더스트래블
# 1950하우스
# 석다원
# 팜알로하
# 가비오타카페
# 인어공주
# 파스쿠찌 도남점
# 빌레왓
# 감저카페
# 하효소머리국밥
# 키아스마
# 아따블르
# 제일식당
# 코끼리통닭
# 벨롱
# 몬스터살롱
# 나까무라
# 엉또산장
# 빠라빠빵
# 송당나무
# 장승포식당
# 서바당횟집
# 원조마라도짜장면
# 카페비글
# 은혜전복
# 고망딱새
# 르에스까르고
# 하례정원
# 부르네비어가든
# 동구미
# 강정해녀의집
# 카페 소바니
# 수타명가
# 블루메베이글
# 커피림
# 문게야
# 바당꺼몬딱
# 엉클통김밥(본점)
# 다가미(도남)
# 카페비몽
# 고향향토장터
# 명당양과
# 몽키비치클럽 Monkey Beach
# 오데뜨
# 그옛맛
# 상춘재
# 새빌
# 제주샘주 영농협동조합
# 양촌리마을
# 하효살롱
# 오마이양대창 제주외도점
# 하와유제주
# 카페콧수염
# 그랜드 키친
# 제주기정떡
# 복자씨연탄구이
# 텍시아
# 제주웅담
# 웬드구니
# 거인의 정원
# 노을과 어울림 카페
# 국수바다 본점
# 공천포식당
# 내창생태카페
# 짜장면시키신분 마라점
# 제주시 새우리
# 고내촌한정식
# 무상찻집
# 녹나무
# 섬마을청년회관
# 웅스키친
# 빠빠라기
# 영해식당 (제주점)
# 커피앤빵
# 바그다드
# 종이시계 카페
# 피자아일랜드
# 베이크샵스니프
# 제주뚝배기
# 오메오메
# 소반
# 제리스펍
# 하몽인제주
# 손맛촌
# 노네임드봉개
# 양가형제
# 파리바게트 애월
# 블랑로쉐
# 커피코알라
# 서귀포바당물회
# 소길역
# 안녕구움
# 블리케이크
# 24시 전주명가콩나물국밥
# 어머니와고등어
# 블루밍제이
# 성산일출봉 해송갈치전문점
# 명물
# 봉끄랑횟집
# 문어빵굽는문빵9
# 모슬포에서
# 제주중문수제맥주
# 델리
# 정가네 밥상
# 어머니의뜻을담다 단지
# 커피먹는 고냉이
# 사이카레
# 종달해녀의집
# 늘푸른농원 연리지가든
# 채점석베이커리
# 앙뚜아네트 탑동점
# 쁠랑뜨
# 구이향연동점
# 흑돼지신화
# 쫑이네해산물
# 성미가든
# 연화키친
# 쿡이야
# 월령203
# 바람카페
# 도리화과
# 숨비나리
# 이노우에스시
# 동그라미식육식당(돈델리)
# 몬스테라 자구리
# 한림칼국수
# 알라스카인제주 협재점
# 컬쳐드
# 옐로우카페 (yellow cafe)
# 블루하우스
# 성춘(토종순대)
# 제주 어가
# 키친오즈
# 흑돈향
# 지미스
# 민봉태중화요리
# 동복리해녀촌
# 바보카페
# 성산진미식당
# 북촌에가면
# 배롱개
# 풍림다방
# 섬소나이
# 요리하는 목수
# 포트그릴 스테이크하우스
# 수다뜰
# 쉬림프박스
# 낭만주의
# 로뎀가든
# 그리다앤쿡
# 녹원전통찻집
# 살롱드라방 SALON de LAVANT
# 카페세바
# 일통이반
# 비어라운드(Be around)
# 매기의 추억
# 산방식당(모슬포본점)
# 와팡
# 평대스낵
# 바당봉봉
# 한라앤탐
# 서문수산
# 고래라면
# 해월정
# 귀빈식당
# 탑부평
# 오라숲소리
# 제주삼다국수
# 에스프레소 라운지
# 고벤져스(본점)
# 열공부엌
# 종달리엔 엄마식당
# 맛나식당
# 오끼416갤러리
# 포차
# 거부한정식(신제주점)
# 우유부단
# 카페2085
# 하하호호(HAHAHOHO)
# 흑돼지킹생구이전문점
# 옹포별장가든
# 좀녀마을뚝배기
# 아줄레주
# 로스터리카페 담담
# 용림식당
# 경주네횟집
# 새벽숯불가든
# 아톰스낵
# 카페코지
# 세가름
# 흑돼지촌
# 방긋스낵
# 하누가물애
# 이성필 커피볶는집
# 미친부엌
# 성미식당
# 국수마당
# 망고홀릭 성산일출봉점
# 제대가는길
# 루스트플레이스 노형점
# 카페힐스
# 일출봉쑥빵보리빵
# 해뜨는식당
# 비자블라썸
# 성아시
# 제주침시술소바 (오로라식품)
# 나목도식당
# 조아찌
# 갈치 카페
# 고집돌우럭(중문)
# 카페더몹시
# 성신흑돼지
# 감초식당
# 몽상드애월(몽상)
# 다담은
# 망고레이 함덕점
# 유동커피
# 번개피자
# 아일랜드조르바
# 물회영해초영
# 청해원
# 쌍둥이횟집본점
# 모시란
# 버거307 협재점
# 서울분식
# 킴스커틀렛
# 바다풍경횟집
# 자매국수 본점
# 돈카츠서황
# 함덕해물라면오빠네
# 딤섬9898
# 지금이순간
# 당케올레국수
# 우도면파전리
# 랜딩 다이닝(Landing dining)
# 사우스바운더
# 제주광해 애월
# 르 쉬느아 (Le Chinois)
# 숨어있는집
# 델문도
# 누옥
# 흑소랑
# 카페공작소
# 마틸다
# 미풍해장국 신제주점
# 더클리프
# 애월더선셋
# 흑돈가
# 다래향 세화점
# 헬로키티아일랜드카페
# 88버거
# 연동마라도횟집
# 제주신화월드 F&B
# 24시누름돌김치찌개
# 서귀포네거리식당
# 신화돌담집
# 보스코화덕피자
# 도도톳김밥
# 나무카페
# 칠돈가 본점
# 깡촌흑돼지
# 김명자굴국밥(제주본점)
# 황금손가락
# 윌라라
# 핀크스 비오토피아
# 스시도모다찌 칠성점
# 더파크뷰(신라호텔)
# 스마일러 카페
# 돌카롱 애월점
# 어진이네횟집
# 제주그림카페
# 닐모리동동
# 숙이네보리빵
# 명랑스낵
# 만원의행복
# 넉둥베기 고사리육개장
# 바다속고등어쌈밥
# 도나토스
# 수두리보말칼국수
# 협재해녀의집
# 만덕이네
# 제주미향
# 카이로스
# 가시아방
# 질그랭이센터
# 비브레이브커피로스터스
# 글라글라하와이
# 볼스프로덕션
# 공단해장국
# 서진향해장국
# 요요무문
# 병천한가네순대국밥
# 선흘곶
# 마노르블랑
# 모루쿠다
# 노을해안1014
# 골목집갈치와고등어
# 어제보다오늘
# 두툼한고기돈돼지
# 산지물식당(건입동본점)
# 인그리드
# 카페빠네띠에
# 오가네전복설렁탕
# 토계정
# 濟州膳제주선
# 봉끄랑
# 도두해녀의집
# 대니스카페
# 우진해장국
# 제주크랩잭
# 보목해녀의집
# 피즈
# 고요남
# 목포고을
# 헤이브라더
# 노라바
# 성산해녀짬뽕
# 로이앤메이
# 뜰향기
# 김희선몸국
# 돌하르방식당
# 미래뷔페정식
# 스카이 온 파이브 다이닝
# And유Café
# 감나무집
# 용담밭담
# 돼지굽는정원
# 라운지 38
# 맛있는 여가생활
# 공백
# 명성식당
# 명진전복
# 리치망고
# 타무라
# 신우성타운
# 올래국수
# 월정리에서브런치
# 테라로사
# 카페콜라
# 돈사돈
# 구좌상회
# 엘리펀시아
# 수우동
# 제주맥주 양조장
# 뉴저지카페
# 우도해광식당
# 전원일기
# 우도왕자이야기
# 이오리
# 슬슬슬로우
# 바다다
# 운정이네
# 오드랑베이커리
# 마님순대
# 월정리로와
# 순옥이네 명가
# 대운정
# 벵디
# 우도 풍원
# 원앤온리
# 우유부단 크림공작소
# 국수의전설
# 파리바게뜨 성산일출봉점
# 함덕밀면
# 오조해녀의 집
# 성산회관
# 피어22
# 사해방흑돼지
# 메종드쁘띠푸루
# 돌토고리족욕카페
# 우무(umu)
# 시영통닭
# 위미항활어회센터
# 리틀비엣
# 백기해녀의 집
# 행복미가
# 제주김만복(만복이네김밥집)
# 앤트러사이트
# 제라한보쌈
# 서연의집(영화 건축학개론)
# 쇼밥
# 겹겹의 의도
# 반딧불한담
# 부자식당
# 중앙식당
# 천제연토속음식점
# 진미명가식당
# 시나르
# 제주진미마돈가
# 루스트플레이스 시청점
# 땅꼬분식 뷔페
# 루스트플레이스 제원점
# 인풍감자탕
# 어머니닭집
# 카페마니
# 붉은제주
# 명월국민학교
# 봄날카페
# 소라의성

# %%
import pandas as pd

# %%
pd.DataFrame(jeju_food['items'])#.to_csv('D:/bigdata0214/final_proj/jeju_project/crawling/dddd2.csv', encoding='')
# Out:
#                                                  alltag            contentsid  \
# 0     추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,...  CNTS_200000000009113
# 1     삼화, 순두부요리, 전골요리,화장실,무료 WIFI,일품순두부, 해장순두부, 두부전골...  CNTS_200000000012653
# 2     추자음식점,추자식당,추자향토음식점,추자회식당,추자도,음식,한치물회,전복물회,물회,고...  CNTS_200000000009101
# 3                                              순두부,두부전골  CNTS_200000000013323
# 4                                        부모,휴식/힐링, 채식주의  CNTS_200000000007243
# ...                                                 ...                   ...
# 1637  카페,커피,아메리카노,공용주차장,현금결제,카드결제,화장실,무료 WIFI,음료대,유도...  CNTS_000000000020069
# 1638      삼합,전복,두루치기,공용주차장,현금결제,카드결제,화장실,무료 WIFI,아주 어려움  CNTS_000000000020478
# 1639                      갤러리, 카페, 커피,화장실,무료 WIFI,공용주차장  CNTS_200000000008010
# 1640          카페,커피,음료,현금결제,카드결제,화장실,무료 WIFI,음료대,아주 어려움  CNTS_000000000018337
# 1641                                   건축물, 북카페, 전시,화장실  CNTS_200000000008034
#
#                                              contentscd     title  \
# 0     {'value': 'c4', 'label': '음식점', 'refId': 'cont...   황금섬숯불갈비
# 1     {'value': 'c4', 'label': '음식점', 'refId': 'cont...  일품순두부삼화점
# 2     {'value': 'c4', 'label': '음식점', 'refId': 'cont...       해적선
# 3     {'value': 'c4', 'label': '음식점', 'refId': 'cont...     제주콩순옥
# 4     {'value': 'c4', 'label': '음식점', 'refId': 'cont...      자연으로
# ...                                                 ...       ...
# 1637  {'value': 'c4', 'label': '음식점', 'refId': 'cont...      카페마니
# 1638  {'value': 'c4', 'label': '음식점', 'refId': 'cont...      붉은제주
# 1639  {'value': 'c4', 'label': '음식점', 'refId': 'cont...    명월국민학교
# 1640  {'value': 'c4', 'label': '음식점', 'refId': 'cont...      봄날카페
# 1641  {'value': 'c1', 'label': '관광지', 'refId': 'cont...      소라의성
#
#                                               region1cd  \
# 0     {'value': 'region3', 'label': '섬 속의 섬', 'refId...
# 1     {'value': 'region1', 'label': '제주시', 'refId': ...
# 2     {'value': 'region3', 'label': '섬 속의 섬', 'refId...
# 3     {'value': 'region2', 'label': '서귀포시', 'refId':...
# 4     {'value': 'region2', 'label': '서귀포시', 'refId':...
# ...                                                 ...
# 1637  {'value': 'region1', 'label': '제주시', 'refId': ...
# 1638  {'value': 'region1', 'label': '제주시', 'refId': ...
# 1639  {'value': 'region1', 'label': '제주시', 'refId': ...
# 1640  {'value': 'region1', 'label': '제주시', 'refId': ...
# 1641  {'value': 'region2', 'label': '서귀포시', 'refId':...
#
#                                               region2cd  \
# 0     {'value': '32', 'label': '추차도', 'refId': 'regi...
# 1     {'value': '11', 'label': '제주시내', 'refId': 'reg...
# 2     {'value': '32', 'label': '추차도', 'refId': 'regi...
# 3     {'value': '22', 'label': '대정', 'refId': 'regio...
# 4     {'value': '17', 'label': '성산', 'refId': 'regio...
# ...                                                 ...
# 1637  {'value': '16', 'label': '구좌', 'refId': 'regio...
# 1638  {'value': '12', 'label': '애월', 'refId': 'regio...
# 1639  {'value': '13', 'label': '한림', 'refId': 'regio...
# 1640  {'value': '12', 'label': '애월', 'refId': 'regio...
# 1641  {'value': '21', 'label': '서귀포시내', 'refId': 're...
#
#                            address                   roadaddress  \
# 0        제주특별자치도 제주시 추자면 대서리 140-6        제주특별자치도 제주시 추자면 추자로 36
# 1         제주특별자치도 제주시 삼양이동 2176-14          제주특별자치도 제주시 삼봉로2길 54
# 2        제주특별자치도 제주시 추자면 대서리 144-1      제주특별자치도 제주시 추자면 추자로 42-1
# 3       제주특별자치도 서귀포시 대정읍 하모리 857-8    제주특별자치도 서귀포시 대정읍 신영로 129-2
# 4     제주특별자치도 서귀포시 성산읍 삼달리 1079-13   제주특별자치도 서귀포시 성산읍 중산간동로 4217
# ...                            ...                           ...
# 1637    제주특별자치도 제주시 구좌읍 평대리 2033-1   제주특별자치도 제주시 구좌읍 해맞이해안로 1112
# 1638    제주특별자치도 제주시 애월읍 애월리 2482-1        제주특별자치도 제주시 애월읍 애월로 37
# 1639      제주특별자치도 제주시 한림읍 명월리 1734        제주특별자치도 제주시 한림읍 명월로 48
# 1640      제주특별자치도 제주시 애월읍 애월리 2540      제주특별자치도 제주시 애월읍 애월로1길 25
# 1641        제주특별자치도 서귀포시 동홍동 234-8  제주특별자치도 서귀포시 칠십리로214번길 17-17
#
#                                                     tag  \
# 0     추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,...
# 1                                   삼화,순두부요리,전골요리,음식,식당
# 2     추자음식점,추자식당,추자향토음식점,추자회식당,추자도,음식,한치물회,전복물회,물회,고...
# 3                          순두부,두부전골,안심채움,맛있는제주만들기,음식,식당
# 4                부모,휴식/힐링,채식주의,음식,간장게장,돔베고기,고등어구이,정식,수육
# ...                                                 ...
# 1637               카페,커피,아메리카노,음식,에스프레소,카페라떼,차,에이드,과일주스
# 1638                            삼합,전복,두루치기,음식,고등어구이,고등어
# 1639        갤러리,카페,커피,음식,차,청귤차,꽃차,아메리카노,바닐라라떼,카페라떼,녹차라떼
# 1640  카페,커피,음료,음식,콜드브루,아메리카노,바닐라라떼,카페라떼,아인슈페너,카푸치노,카...
# 1641                         건축물,북카페,전시,실내관광지,문화관광,어트랙션
#
#                                            introduction  ...  postcode  \
# 0                                     추자에서 즐기는 제주산 돼지고기  ...      None
# 1     일품순두부는 다양한 종류의 순두부찌개는 물론 소불고기뚝배기, 제육볶음 등의 추가메뉴...  ...      None
# 2                           추자도에서 잡히는 싱싱한 생선으로 요리하는 음식점  ...      None
# 3     제주콩순옥은 2016년 호텔신라의 레시피 전수와 리모델링 지원을 통해 재개장한 ‘맛...  ...      None
# 4                                           자연주의 전문 음식점  ...      None
# ...                                                 ...  ...       ...
# 1637  빨간 소파에 누워 에메랄드빛 바다를 바라보며 커피한잔을 즐길 수 있는 테마로 유명한 카페  ...     63360
# 1638                              싱싱한 해산물과 흑돼지가 어우러진 요리  ...     63043
# 1639                                폐교가 카페와 갤러리로 재탄생된 곳  ...      None
# 1640                          드라마 '맨도롱 또똣'의 주인공이 일하던 카페  ...     63043
# 1641                                 해안절벽에 지어진 아름다운 건축물  ...      None
#
#              phoneno                                               sbst  \
# 0       064-742-0478           65명 수용가능한 단체가능석에 육고기 요리와 생선요리를 같이 파는 음식점
# 1       064-722-0434  제주시내를 빠져나가 삼양해수욕장으로 향하는 길목에 위치하고 있는 일품순두부삼화점는 ...
# 2      010-8623-8229                  추자도에서 잡히는 생선들로 구성되는 메뉴들을 보유한 음식점
# 3       064-792-8585
# 4       064-782-2831  자연 속으로 풍덩 빠져든 것 같은 느낌을 주는 인테리어와 음식. 직접 농사를 지어 ...
# ...              ...                                                ...
# 1637   010-7129-7533  월정리 너머 평대리에 위치하며 파티플래너로 오랫동안 일을 해왔던 주인장님이 운영하는...
# 1638    064-744-9123                                               None
# 1639   070-8803-1955  1955년부터 1993년까지 40여 년 가까이 명월리 아이들의 배움터이자 놀이터였던...
# 1640    064-799-4999  드라마의 주인공이 일하던 카페라서 유명해졌다. ​​​​​​​\n해변을 바라보며 차 ...
# 1641    064-732-7128   소라의성은 서귀포시 동홍동에 있는 아름다운 건축물로 단순하면서도 곡선의 아름다움이...
#
#              created         changed  \
# 0     20190820152943  20220708114819
# 1     20220103141504  20220710080539
# 2     20190820140605  20220711140538
# 3     20220428114210  20220711203049
# 4     20180717173314  20220711221528
# ...              ...             ...
# 1637  20161104164555  20220714124618
# 1638  20161122131433  20220714123711
# 1639  20181217165631  20220714123721
# 1640  20161006133518  20220714123950
# 1641  20181220110729  20220714124215
#
#                                            catemappList  festivalcontents  \
# 0     [{'seq': 30792, 'contentsid': {'value': 'CNTS_...              None
# 1     [{'seq': 29588, 'contentsid': {'value': 'CNTS_...              None
# 2     [{'seq': 30803, 'contentsid': {'value': 'CNTS_...              None
# 3     [{'seq': 30682, 'contentsid': {'value': 'CNTS_...              None
# 4     [{'seq': 26816, 'contentsid': {'value': 'CNTS_...              None
# ...                                                 ...               ...
# 1637  [{'seq': 26532, 'contentsid': {'value': 'CNTS_...              None
# 1638  [{'seq': 1656, 'contentsid': {'value': 'CNTS_0...              None
# 1639  [{'seq': 20545, 'contentsid': {'value': 'CNTS_...              None
# 1640  [{'seq': 26355, 'contentsid': {'value': 'CNTS_...              None
# 1641  [{'seq': 10678, 'contentsid': {'value': 'CNTS_...              None
#
#                                                repPhoto  PHOTOSHARECOUNT  \
# 0     {'descseo': '황금섬숯불갈비', 'photoid': {'photoid': ...              0.0
# 1     {'descseo': '일품순두부삼화점', 'photoid': {'photoid':...              0.0
# 2     {'descseo': '해적선', 'photoid': {'photoid': 2019...              0.0
# 3     {'descseo': '제주콩순옥', 'photoid': {'photoid': 20...              0.0
# 4     {'descseo': '뉴자연으로', 'photoid': {'photoid': 20...              0.0
# ...                                                 ...              ...
# 1637  {'descseo': '카페마니', 'photoid': {'photoid': 201...             24.0
# 1638  {'descseo': '붉은제주', 'photoid': {'photoid': 874...              6.0
# 1639  {'descseo': '명월국민학교', 'photoid': {'photoid': 2...              0.0
# 1640  {'descseo': 'Spring Day Café', 'photoid': {'ph...            229.0
# 1641  {'descseo': '소라의성', 'photoid': {'photoid': 201...              0.0
#
#       reservelink
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 1637         None
# 1638         None
# 1639         None
# 1640         None
# 1641         None
#
# [1642 rows x 30 columns]
