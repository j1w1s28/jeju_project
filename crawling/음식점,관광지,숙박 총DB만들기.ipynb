# %%
import pandas as pd

# %%
test = pd.read_csv('../data/jeju_food_modified.csv')

# %%
# 1차 검색 제주 000 
url = 'https://map.naver.com/v5/api/search'
params = {
    'calller': 'pcweb',
    'query': '',
    'type': 'all',
    'searchCoord': '126.56379330000001;33.24652849999992',
    'page': 1,
    'displayCount': 20,
    'isPlaceRecommendationReplace': True,
    'lang': 'ko'
}
tmp_dict = dict()
headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    'cookie': 'NNB=SFVP2LHVPD7WC; NDARK=N; _gcl_au=1.1.876992382.1652928740; _fbp=fb.1.1652928739593.996991756; _ga=GA1.2.1723077753.1655082737; MM_NEW=1; NFS=2; _tt_enable_cookie=1; _ttp=d30a8fad-c361-4bb2-a6d7-884e4f9ca1c6; NV_WETR_LOCATION_RGN_M="MDkxNDAxMDQ="; NV_WETR_LAST_ACCESS_RGN_M="MDkxNDAxMDQ="; nx_ssl=2; csrf_token=b22420dac145f9757a431121f5b4c25948818847853c526728a4d2219155c97e9b6490d088524f5e2d1f9fdd189f23d95bdd86f6e9ca8c8b07bf30c857e040c6; page_uid=d78aa3bb-613a-4eab-8035-b9c4712fa1de',
    'expires': 'Sat, 01 Jan 2000 00:00:00 GMT',
    'pragma': 'no-cache',
    'referer': 'https://map.naver.com/',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
}
params2 ={
    'lang' :'ko'
}
#n차 검색 제주도 주소 검색 후 해당 위치의 가게 정보를 조회 
url3 = 'https://map.naver.com/v5/api/addresses/place/'
params3= {
    'address':'',
    'lang':'ko',
    'page':1
}
headers2 = {
    'authority': 'map.naver.com',
    'accept': 'application/json, text/plain, */*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    'cookie': 'NNB=SFVP2LHVPD7WC; NDARK=N; _gcl_au=1.1.876992382.1652928740; _fbp=fb.1.1652928739593.996991756; _ga=GA1.2.1723077753.1655082737; MM_NEW=1; NFS=2; _tt_enable_cookie=1; _ttp=d30a8fad-c361-4bb2-a6d7-884e4f9ca1c6; NV_WETR_LOCATION_RGN_M="MDkxNDAxMDQ="; NV_WETR_LAST_ACCESS_RGN_M="MDkxNDAxMDQ="; nx_ssl=2; page_uid=hXuWqwp0YiRssBM4BUGssssssMo-163853; BMR=s=1658907970093&r=https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=heygun&logNo=221520454294&r2=https://www.google.com/; page_uid=3c7d105d-de2b-4c43-8a74-1c2abebf354d',
    'expires': 'Sat, 01 Jan 2000 00:00:00 GMT',
    'pragma ': 'no-cache',
    'referer': 'https://map.naver.com/',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
}
# Out:
# 16906907      9
# 11714447      8
# 13418405      8
# 33225737      7
# 16966744      7
#              ..
# 1351665299    1
# 16746102      1
# 1533749235    1
# 1835542236    1
# 1822308478    1
# Name: id, Length: 9370, dtype: int64

# %%
# Out:
#                                                  alltag            contentsid  \
# 0     추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,...  CNTS_200000000009113
# 1     삼화, 순두부요리, 전골요리,화장실,무료 WIFI,일품순두부, 해장순두부, 두부전골...  CNTS_200000000012653
# 2     추자음식점,추자식당,추자향토음식점,추자회식당,추자도,음식,한치물회,전복물회,물회,고...  CNTS_200000000009101
# 3                                              순두부,두부전골  CNTS_200000000013323
# 4                                        부모,휴식/힐링, 채식주의  CNTS_200000000007243
# ...                                                 ...                   ...
# 1637  카페,커피,아메리카노,공용주차장,현금결제,카드결제,화장실,무료 WIFI,음료대,유도...  CNTS_000000000020069
# 1638      삼합,전복,두루치기,공용주차장,현금결제,카드결제,화장실,무료 WIFI,아주 어려움  CNTS_000000000020478
# 1639                      갤러리, 카페, 커피,화장실,무료 WIFI,공용주차장  CNTS_200000000008010
# 1640          카페,커피,음료,현금결제,카드결제,화장실,무료 WIFI,음료대,아주 어려움  CNTS_000000000018337
# 1641                                   건축물, 북카페, 전시,화장실  CNTS_200000000008034
#
#      contentscd     title                       address  \
# 0           음식점   황금섬숯불갈비     제주특별자치도 제주시 추자면 대서리 140-6
# 1           음식점  일품순두부삼화점      제주특별자치도 제주시 삼양이동 2176-14
# 2           음식점       해적선     제주특별자치도 제주시 추자면 대서리 144-1
# 3           음식점     제주콩순옥    제주특별자치도 서귀포시 대정읍 하모리 857-8
# 4           음식점      자연으로  제주특별자치도 서귀포시 성산읍 삼달리 1079-13
# ...         ...       ...                           ...
# 1637        음식점      카페마니    제주특별자치도 제주시 구좌읍 평대리 2033-1
# 1638        음식점      붉은제주    제주특별자치도 제주시 애월읍 애월리 2482-1
# 1639        음식점    명월국민학교      제주특별자치도 제주시 한림읍 명월리 1734
# 1640        음식점      봄날카페      제주특별자치도 제주시 애월읍 애월리 2540
# 1641        관광지      소라의성        제주특별자치도 서귀포시 동홍동 234-8
#
#                        roadaddress  \
# 0           제주특별자치도 제주시 추자면 추자로 36
# 1             제주특별자치도 제주시 삼봉로2길 54
# 2         제주특별자치도 제주시 추자면 추자로 42-1
# 3       제주특별자치도 서귀포시 대정읍 신영로 129-2
# 4      제주특별자치도 서귀포시 성산읍 중산간동로 4217
# ...                            ...
# 1637   제주특별자치도 제주시 구좌읍 해맞이해안로 1112
# 1638        제주특별자치도 제주시 애월읍 애월로 37
# 1639        제주특별자치도 제주시 한림읍 명월로 48
# 1640      제주특별자치도 제주시 애월읍 애월로1길 25
# 1641  제주특별자치도 서귀포시 칠십리로214번길 17-17
#
#                                                     tag  \
# 0     추자갈비,추자오겹살,추자장어구이,추자음식점,추자식당,추자도,음식,양념왕갈비,오겹살,...
# 1                                   삼화,순두부요리,전골요리,음식,식당
# 2     추자음식점,추자식당,추자향토음식점,추자회식당,추자도,음식,한치물회,전복물회,물회,고...
# 3                          순두부,두부전골,안심채움,맛있는제주만들기,음식,식당
# 4                부모,휴식/힐링,채식주의,음식,간장게장,돔베고기,고등어구이,정식,수육
# ...                                                 ...
# 1637               카페,커피,아메리카노,음식,에스프레소,카페라떼,차,에이드,과일주스
# 1638                            삼합,전복,두루치기,음식,고등어구이,고등어
# 1639        갤러리,카페,커피,음식,차,청귤차,꽃차,아메리카노,바닐라라떼,카페라떼,녹차라떼
# 1640  카페,커피,음료,음식,콜드브루,아메리카노,바닐라라떼,카페라떼,아인슈페너,카푸치노,카...
# 1641                         건축물,북카페,전시,실내관광지,문화관광,어트랙션
#
#                                            introduction  readcnt  likecnt  \
# 0                                     추자에서 즐기는 제주산 돼지고기      376        0
# 1     일품순두부는 다양한 종류의 순두부찌개는 물론 소불고기뚝배기, 제육볶음 등의 추가메뉴...       21        0
# 2                           추자도에서 잡히는 싱싱한 생선으로 요리하는 음식점      442        0
# 3     제주콩순옥은 2016년 호텔신라의 레시피 전수와 리모델링 지원을 통해 재개장한 ‘맛...       81        0
# 4                                           자연주의 전문 음식점     1111        0
# ...                                                 ...      ...      ...
# 1637  빨간 소파에 누워 에메랄드빛 바다를 바라보며 커피한잔을 즐길 수 있는 테마로 유명한 카페     7238        4
# 1638                              싱싱한 해산물과 흑돼지가 어우러진 요리    13838        5
# 1639                                폐교가 카페와 갤러리로 재탄생된 곳     7952        2
# 1640                          드라마 '맨도롱 또똣'의 주인공이 일하던 카페    61794       45
# 1641                                 해안절벽에 지어진 아름다운 건축물     4205        0
#
#       ...  evelpt   latitude   longitude         phoneno  \
# 0     ...     0.0  33.963678  126.295766    064-742-0478
# 1     ...     0.0  33.519579  126.582360    064-722-0434
# 2     ...     0.0  33.962759  126.295205   010-8623-8229
# 3     ...     0.0  33.223406  126.254902    064-792-8585
# 4     ...     0.0  33.378381  126.840309    064-782-2831
# ...   ...     ...        ...         ...             ...
# 1637  ...     4.0  33.537370  126.837430   010-7129-7533
# 1638  ...     5.0  33.462128  126.312280    064-744-9123
# 1639  ...     5.0  33.388832  126.264948   070-8803-1955
# 1640  ...     5.0  33.462460  126.309590    064-799-4999
# 1641  ...     0.0  33.266320  126.567173    064-732-7128
#
#                                                    sbst  PHOTOSHARECOUNT  \
# 0              65명 수용가능한 단체가능석에 육고기 요리와 생선요리를 같이 파는 음식점              0.0
# 1     제주시내를 빠져나가 삼양해수욕장으로 향하는 길목에 위치하고 있는 일품순두부삼화점는 ...              0.0
# 2                     추자도에서 잡히는 생선들로 구성되는 메뉴들을 보유한 음식점               0.0
# 3                                                   NaN              0.0
# 4     자연 속으로 풍덩 빠져든 것 같은 느낌을 주는 인테리어와 음식. 직접 농사를 지어 ...              0.0
# ...                                                 ...              ...
# 1637  월정리 너머 평대리에 위치하며 파티플래너로 오랫동안 일을 해왔던 주인장님이 운영하는...             24.0
# 1638                                                NaN              6.0
# 1639  1955년부터 1993년까지 40여 년 가까이 명월리 아이들의 배움터이자 놀이터였던...              0.0
# 1640  드라마의 주인공이 일하던 카페라서 유명해졌다. ???????\r\n해변을 바라보며 ...            229.0
# 1641   소라의성은 서귀포시 동홍동에 있는 아름다운 건축물로 단순하면서도 곡선의 아름다움이...              0.0
#
#       cate2cd  cate3cd                                            imgpath  \
# 0          한식       한식  https://api.cdn.visitjeju.net/photomng/imgpath...
# 1          한식       한식  https://api.cdn.visitjeju.net/photomng/imgpath...
# 2        향토음식     향토음식  https://api.cdn.visitjeju.net/photomng/imgpath...
# 3          한식       한식  https://api.cdn.visitjeju.net/photomng/imgpath...
# 4          한식       한식  https://api.cdn.visitjeju.net/photomng/imgpath...
# ...       ...      ...                                                ...
# 1637       카페       카페  https://api.cdn.visitjeju.net/photomng/imgpath...
# 1638       한식       한식  https://api.cdn.visitjeju.net/photomng/imgpath...
# 1639       카페       카페  https://api.cdn.visitjeju.net/photomng/imgpath...
# 1640       카페       카페  https://api.cdn.visitjeju.net/photomng/imgpath...
# 1641     문화관광       그외  https://api.cdn.visitjeju.net/photomng/imgpath...
#
#                                           thumbnailpath
# 0     https://api.cdn.visitjeju.net/photomng/thumbna...
# 1     https://api.cdn.visitjeju.net/photomng/thumbna...
# 2     https://api.cdn.visitjeju.net/photomng/thumbna...
# 3     https://api.cdn.visitjeju.net/photomng/thumbna...
# 4     https://api.cdn.visitjeju.net/photomng/thumbna...
# ...                                                 ...
# 1637  https://api.cdn.visitjeju.net/photomng/thumbna...
# 1638  https://api.cdn.visitjeju.net/photomng/thumbna...
# 1639  https://api.cdn.visitjeju.net/photomng/thumbna...
# 1640  https://api.cdn.visitjeju.net/photomng/thumbna...
# 1641  https://api.cdn.visitjeju.net/photomng/thumbna...
#
# [1642 rows x 25 columns]

# %%
restaurant2=restaurant1[restaurant1['fullAddress'].str.contains('제주특별자치도')]

# %%
restaurant2.drop_duplicates(subset='id',ignore_index=True,inplace=True)
# Out:
# C:\Users\TJ\AppData\Local\Temp\ipykernel_13356\805190792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant2.drop_duplicates(subset='id',ignore_index=True,inplace=True)

# %%
restaurant2['categories'].value_counts()
# Out:
# ['음식점', '한식']          1894
# ['음식점', '카페,디저트']       641
# ['한식', '육류,고기요리']       400
# ['음식점', '치킨,닭강정']       386
# ['술집', '맥주,호프']         344
#                        ...
# ['중식', '딤섬,중식만두']         1
# ['해장국', '미향해장국']          1
# ['짚라인']                   1
# ['임대,대여', '오토바이']         1
# ['전통,민속주점', '민속주점']       1
# Name: categories, Length: 256, dtype: int64
