# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time

# %%
naver_map_url = 'https://pcmap-api.place.naver.com/graphql'
naver_map_get = 'https://pcmap.place.naver.com/restaurant/list'
params = {
    'query':'제주도맛집',
    'x':126.30804269999975,
    'y':33.42733659999997,
    'bounds':'126.233885;32.9636448;126.9315168;33.8771638',
    'entry':'bmp',
    'rank':'많이찾는',
    'deviceType':'pcmap'
}

# %%
startnum = [i for i in range(1,20279,100)]

# %%
time.sleep(1)
startnum[202]
# Out:
# 20201

# %%
json_list = []
for i in range(203):
    data = [{
    'operationName':'getRestaurants',
    'query': "query getRestaurants($restaurantListInput: RestaurantListInput, $restaurantListFilterInput: RestaurantListFilterInput) {\n  restaurants: restaurantList(input: $restaurantListInput) {\n    total\n    items {\n      id\n      name\n      category\n      hasBooking\n      imageUrl\n      address\n      isTableOrder\n      isPreOrder\n      isTakeOut\n      dbType\n      businessCategory\n      description\n      hasNPay\n      x\n      y\n      distance\n      imageUrls\n      imageCount\n      phone\n      virtualPhone\n      routeUrl\n      streetPanorama {\n        id\n        tilt\n        pan\n        lat\n        lon\n        __typename\n      }\n      roadAddress\n      commonAddress\n      fullAddress\n      blogCafeReviewCount\n      bookingReviewCount\n      totalReviewCount\n      bookingReviewScore\n      bookingUrl\n      bookingHubUrl\n      bookingHubButtonName\n      bookingBusinessId\n      talktalkUrl\n      options\n      promotionTitle\n      agencyId\n      businessHours\n      microReview\n      tags\n      priceCategory\n      broadcastInfo {\n        program\n        date\n        menu\n        __typename\n      }\n      michelinGuide {\n        year\n        star\n        comment\n        url\n        hasGrade\n        isBib\n        alternateText\n        __typename\n      }\n      broadcasts {\n        program\n        menu\n        episode\n        broadcast_date\n        __typename\n      }\n      tvcastId\n      naverBookingCategory\n      saveCount\n      uniqueBroadcasts\n      isDelivery\n      isCvsDelivery\n      isTableOrder\n      isPreOrder\n      isTakeOut\n      bookingDisplayName\n      bookingVisitId\n      bookingPickupId\n      popularMenuImages {\n        name\n        price\n        bookingCount\n        menuUrl\n        menuListUrl\n        imageUrl\n        isPopular\n        usePanoramaImage\n        __typename\n      }\n      visitorReviewCount\n      visitorReviewScore\n      newOpening\n      newBusinessHours {\n        status\n        description\n        __typename\n      }\n      foryou {\n        tagName\n        label\n        tasteType\n        reviews {\n          imageUrl\n          profileUrl\n          authorId\n          authorName\n          maskedName\n          contentId\n          __typename\n        }\n        address\n        roadAddress\n        __typename\n      }\n      easyOrder {\n        easyOrderId\n        easyOrderCid\n        businessHours {\n          weekday {\n            start\n            end\n            __typename\n          }\n          weekend {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      baemin {\n        businessHours {\n          deliveryTime {\n            start\n            end\n            __typename\n          }\n          closeDate {\n            start\n            end\n            __typename\n          }\n          temporaryCloseDate {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      yogiyo {\n        businessHours {\n          actualDeliveryTime {\n            start\n            end\n            __typename\n          }\n          bizHours {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      deliveryArea\n      __typename\n    }\n    queryString\n    siteSort\n    restaurantCategory\n    selectedFilter {\n      order\n      rank\n      tvProgram\n      region\n      brand\n      menu\n      food\n      mood\n      purpose\n      sortingOrder\n      takeout\n      orderBenefit\n      cafeFood\n      day\n      time\n      age\n      gender\n      foryouParentGroup\n      myPreference\n      hasMyPreference\n      cafeMenu\n      cafeTheme\n      theme\n      __typename\n    }\n    rcodes\n    location {\n      sasX\n      sasY\n      __typename\n    }\n    optionsForMap {\n      maxZoom\n      minZoom\n      includeMyLocation\n      maxIncludePoiCount\n      center\n      spotId\n      __typename\n    }\n    nlu {\n      ...NluFields\n      __typename\n    }\n    __typename\n  }\n  filters: restaurantListFilter(input: $restaurantListFilterInput) {\n    filters {\n      index\n      name\n      value\n      multiSelectable\n      defaultParams {\n        age\n        gender\n        day\n        time\n        __typename\n      }\n      items {\n        index\n        name\n        value\n        selected\n        representative\n        clickCode\n        laimCode\n        type\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment NluFields on Nlu {\n  queryType\n  user {\n    gender\n    __typename\n  }\n  queryResult {\n    ptn0\n    ptn1\n    region\n    spot\n    tradeName\n    service\n    selectedRegion {\n      name\n      index\n      x\n      y\n      __typename\n    }\n    selectedRegionIndex\n    otherRegions {\n      name\n      index\n      __typename\n    }\n    property\n    keyword\n    queryType\n    nluQuery\n    businessType\n    cid\n    branch\n    forYou\n    franchise\n    titleKeyword\n    location {\n      x\n      y\n      default\n      longitude\n      latitude\n      dong\n      si\n      __typename\n    }\n    noRegionQuery\n    priority\n    showLocationBarFlag\n    themeId\n    filterBooking\n    repRegion\n    repSpot\n    dbQuery {\n      isDefault\n      name\n      type\n      getType\n      useFilter\n      hasComponents\n      __typename\n    }\n    type\n    category\n    menu\n    context\n    __typename\n  }\n  __typename\n}\n",
    'variables':{
        'restaruntListFilterInput':{
            'x': "126.30804269999975",
            'y': "33.42733659999997", 
            'query': "제주도맛집",
            'rank': "많이찾는"
        },
        'restaurantListInput':{
            'bounds': "126.233885;32.9636448;126.9315168;33.8771638",
            'deviceType': "pcmap",
            'display': 100,
            'isCurrentLocationSearch':False ,
            'isPcmap': True,
            'orderBenefit':False ,
            'query': "제주도맛집",
            'rank': "많이찾는",
            'start': startnum[i],
            'takeout':False ,
            'x': "126.30804269999975",
            'y': "33.42733659999997"
        }
    }
    }
    ]
    headers = {
    'accept':'*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ko',
    'content-length': '6165',
    'content-type': 'application/json',
    'cookie': 'NNB=SFVP2LHVPD7WC; NDARK=N; _gcl_au=1.1.876992382.1652928740; _fbp=fb.1.1652928739593.996991756; _ga=GA1.2.1723077753.1655082737; MM_NEW=1; NFS=2; nx_ssl=2; _tt_enable_cookie=1; _ttp=d30a8fad-c361-4bb2-a6d7-884e4f9ca1c6; NV_WETR_LOCATION_RGN_M="MDkxNDAxMDQ="; NV_WETR_LAST_ACCESS_RGN_M="MDkxNDAxMDQ="',
    'origin': 'https://pcmap.place.naver.com',
    'referer': 'https://pcmap.place.naver.com/restaurant/list?query=%EC%A0%9C%EC%A3%BC%EB%8F%84%EB%A7%9B%EC%A7%91&x=126.30804269999975&y=33.42733659999997&bounds=126.233885%3B32.9636448%3B126.9315168%3B33.8771638&entry=bmp&rank=%EC%9A%94%EC%A6%98%EB%9C%A8%EB%8A%94&deviceType=pcmap'

    }
    s = requests.Session()
    response=s.post(naver_map_url,headers=headers,data=json.dumps(data))
    if response.status_code==200:
        text = response.json()
        json_list.append(text)
    time.sleep(0.5)

# %%
data = [{
    'operationName':'getRestaurants',
    'query': "query getRestaurants($restaurantListInput: RestaurantListInput, $restaurantListFilterInput: RestaurantListFilterInput) {\n  restaurants: restaurantList(input: $restaurantListInput) {\n    total\n    items {\n      id\n      name\n      category\n      hasBooking\n      imageUrl\n      address\n      isTableOrder\n      isPreOrder\n      isTakeOut\n      dbType\n      businessCategory\n      description\n      hasNPay\n      x\n      y\n      distance\n      imageUrls\n      imageCount\n      phone\n      virtualPhone\n      routeUrl\n      streetPanorama {\n        id\n        tilt\n        pan\n        lat\n        lon\n        __typename\n      }\n      roadAddress\n      commonAddress\n      fullAddress\n      blogCafeReviewCount\n      bookingReviewCount\n      totalReviewCount\n      bookingReviewScore\n      bookingUrl\n      bookingHubUrl\n      bookingHubButtonName\n      bookingBusinessId\n      talktalkUrl\n      options\n      promotionTitle\n      agencyId\n      businessHours\n      microReview\n      tags\n      priceCategory\n      broadcastInfo {\n        program\n        date\n        menu\n        __typename\n      }\n      michelinGuide {\n        year\n        star\n        comment\n        url\n        hasGrade\n        isBib\n        alternateText\n        __typename\n      }\n      broadcasts {\n        program\n        menu\n        episode\n        broadcast_date\n        __typename\n      }\n      tvcastId\n      naverBookingCategory\n      saveCount\n      uniqueBroadcasts\n      isDelivery\n      isCvsDelivery\n      isTableOrder\n      isPreOrder\n      isTakeOut\n      bookingDisplayName\n      bookingVisitId\n      bookingPickupId\n      popularMenuImages {\n        name\n        price\n        bookingCount\n        menuUrl\n        menuListUrl\n        imageUrl\n        isPopular\n        usePanoramaImage\n        __typename\n      }\n      visitorReviewCount\n      visitorReviewScore\n      newOpening\n      newBusinessHours {\n        status\n        description\n        __typename\n      }\n      foryou {\n        tagName\n        label\n        tasteType\n        reviews {\n          imageUrl\n          profileUrl\n          authorId\n          authorName\n          maskedName\n          contentId\n          __typename\n        }\n        address\n        roadAddress\n        __typename\n      }\n      easyOrder {\n        easyOrderId\n        easyOrderCid\n        businessHours {\n          weekday {\n            start\n            end\n            __typename\n          }\n          weekend {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      baemin {\n        businessHours {\n          deliveryTime {\n            start\n            end\n            __typename\n          }\n          closeDate {\n            start\n            end\n            __typename\n          }\n          temporaryCloseDate {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      yogiyo {\n        businessHours {\n          actualDeliveryTime {\n            start\n            end\n            __typename\n          }\n          bizHours {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      deliveryArea\n      __typename\n    }\n    queryString\n    siteSort\n    restaurantCategory\n    selectedFilter {\n      order\n      rank\n      tvProgram\n      region\n      brand\n      menu\n      food\n      mood\n      purpose\n      sortingOrder\n      takeout\n      orderBenefit\n      cafeFood\n      day\n      time\n      age\n      gender\n      foryouParentGroup\n      myPreference\n      hasMyPreference\n      cafeMenu\n      cafeTheme\n      theme\n      __typename\n    }\n    rcodes\n    location {\n      sasX\n      sasY\n      __typename\n    }\n    optionsForMap {\n      maxZoom\n      minZoom\n      includeMyLocation\n      maxIncludePoiCount\n      center\n      spotId\n      __typename\n    }\n    nlu {\n      ...NluFields\n      __typename\n    }\n    __typename\n  }\n  filters: restaurantListFilter(input: $restaurantListFilterInput) {\n    filters {\n      index\n      name\n      value\n      multiSelectable\n      defaultParams {\n        age\n        gender\n        day\n        time\n        __typename\n      }\n      items {\n        index\n        name\n        value\n        selected\n        representative\n        clickCode\n        laimCode\n        type\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment NluFields on Nlu {\n  queryType\n  user {\n    gender\n    __typename\n  }\n  queryResult {\n    ptn0\n    ptn1\n    region\n    spot\n    tradeName\n    service\n    selectedRegion {\n      name\n      index\n      x\n      y\n      __typename\n    }\n    selectedRegionIndex\n    otherRegions {\n      name\n      index\n      __typename\n    }\n    property\n    keyword\n    queryType\n    nluQuery\n    businessType\n    cid\n    branch\n    forYou\n    franchise\n    titleKeyword\n    location {\n      x\n      y\n      default\n      longitude\n      latitude\n      dong\n      si\n      __typename\n    }\n    noRegionQuery\n    priority\n    showLocationBarFlag\n    themeId\n    filterBooking\n    repRegion\n    repSpot\n    dbQuery {\n      isDefault\n      name\n      type\n      getType\n      useFilter\n      hasComponents\n      __typename\n    }\n    type\n    category\n    menu\n    context\n    __typename\n  }\n  __typename\n}\n",
    'variables':{
        'restaruntListFilterInput':{
            'x': "126.30804269999975",
            'y': "33.42733659999997", 
            'query': "제주도맛집",
            'rank': "많이찾는"
        },
        'restaurantListInput':{
            'bounds': "126.233885;32.9636448;126.9315168;33.8771638",
            'deviceType': "pcmap",
            'display': 100,
            'isCurrentLocationSearch':False ,
            'isPcmap': True,
            'orderBenefit':False ,
            'query': "제주도맛집",
            'rank': "많이찾는",
            'start': startnum[1],
            'takeout':False ,
            'x': "126.30804269999975",
            'y': "33.42733659999997"
        }
    }
}
]
headers = {
    'accept':'*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ko',
    'content-length': '6165',
    'content-type': 'application/json',
    'cookie': 'NNB=SFVP2LHVPD7WC; NDARK=N; _gcl_au=1.1.876992382.1652928740; _fbp=fb.1.1652928739593.996991756; _ga=GA1.2.1723077753.1655082737; MM_NEW=1; NFS=2; nx_ssl=2; _tt_enable_cookie=1; _ttp=d30a8fad-c361-4bb2-a6d7-884e4f9ca1c6; NV_WETR_LOCATION_RGN_M="MDkxNDAxMDQ="; NV_WETR_LAST_ACCESS_RGN_M="MDkxNDAxMDQ="',
    'origin': 'https://pcmap.place.naver.com',
    'referer': 'https://pcmap.place.naver.com/restaurant/list?query=%EC%A0%9C%EC%A3%BC%EB%8F%84%EB%A7%9B%EC%A7%91&x=126.30804269999975&y=33.42733659999997&bounds=126.233885%3B32.9636448%3B126.9315168%3B33.8771638&entry=bmp&rank=%EC%9A%94%EC%A6%98%EB%9C%A8%EB%8A%94&deviceType=pcmap'
    
}

# %%
s = requests.Session()
response=s.post(naver_map_url,headers=headers,data=json.dumps(data))
response.status_code
# Out:
# 200

# %%
tmp1 =pd.DataFrame(text_mostviewd[0]['data']['restaurants']['items'])

# %%
response.json()
# Out:
# [{'data': {'restaurants': {'total': 20280,
#     'items': [{'id': '1813647783',
#       'name': '소섬전복',
#       'category': '전복요리',
#       'hasBooking': None,
#       'imageUrl': 'https://ldb-phinf.pstatic.net/20200610_192/1591790911008LgzDp_JPEG/dZ1DRFbUfX4weE5dB-BZNfiZ.jpg',
#       'address': '연평리 329',
#       'isTableOrder': None,
#       'isPreOrder': None,
#       'isTakeOut': None,
#       'dbType': 'drt',
#       'businessCategory': 'restaurant',
#       'description': None,
#       'hasNPay': False,
#       'x': '126.9651221',
#       'y': '33.4988646',
#       'distance': '62km',
#       'imageUrls': ['https://ldb-phinf.pstatic.net/20200610_192/1591790911008LgzDp_JPEG/dZ1DRFbUfX4weE5dB-BZNfiZ.jpg',
#        'https://ldb-phinf.pstatic.net/20200916_83/1600220951276pwLiR_JPEG/LtVDvoN3PJbTGnWf9zToNCGi.jpg',
#        'https://ldb-phinf.pstatic.net/20180921_236/15375107083678hVao_JPEG/XpP6zOI2jcCu_-dDwG0MEcd2.JPG.jpg'],
#       'imageCount': 51,
# ...

# %%
tmp = response.json()

# %%
tmp2=pd.DataFrame(tmp[0]['data']['restaurants']['items'])

# %%
most_viewed_df =pd.concat([tmp1,tmp2],ignore_index=True)

# %%
trendhot = response.json()

# %%
trenhot_1=pd.DataFrame(trendhot[0]['data']['restaurants']['items'])

# %%
trendhot2 = response.json()

# %%
trendhot_2=pd.DataFrame(trendhot2[0]['data']['restaurants']['items'])

# %%
trendhot_df=pd.concat([trenhot_1,trendhot_2],ignore_index=True)

# %%
jeju_food = pd.read_csv('../data/jeju_food_modified.csv')

# %%
json_list[3]
# Out:
# [{'data': {'restaurants': {'total': 0,
#     'items': [],
#     'queryString': None,
#     'siteSort': None,
#     'restaurantCategory': 'restaurant',
#     'selectedFilter': {'order': None,
#      'rank': '많이찾는',
#      'tvProgram': None,
#      'region': None,
#      'brand': None,
#      'menu': None,
#      'food': None,
#      'mood': None,
#      'purpose': None,
#      'sortingOrder': None,
#      'takeout': None,
#      'orderBenefit': None,
#      'cafeFood': None,
#      'day': None,
#      'time': None,
#      'age': None,
#      'gender': None,
#      'foryouParentGroup': None,
#      'myPreference': None,
#      'hasMyPreference': None,
#      'cafeMenu': None,
#      'cafeTheme': None,
#      'theme': None,
#      '__typename': 'SelectedFilter'},
#     'rcodes': '',
#     'location': {'sasX': '', 'sasY': '', '__typename': 'RestaurantLocation'},
#     'optionsForMap': {'maxZoom': 15,
#      'minZoom': 15,
#      'includeMyLocation': None,
#      'maxIncludePoiCount': 0,
# ...

# %%
df
# Out:
#             id         name category hasBooking  \
# 0     13418405        우진해장국     향토음식       None
# 1   1000671392  랜디스도넛 제주애월점       도넛       None
# 2   1142108083           연돈      돈가스       None
# 3     11866447         올래국수       국수       None
# 4   1256246739         원앤온리       카페       None
# ..         ...          ...      ...        ...
# 95    35769744      복자씨연탄구이   돼지고기구이       None
# 96  1622316075        도두후레쉬      햄버거       None
# 97    11714447      쌍둥이횟집본점      생선회       None
# 98    31204698         곰막식당       한식       None
# 99    38335352          바다다   카페,디저트       None
#
#                                              imageUrl  \
# 0   https://ldb-phinf.pstatic.net/20150901_132/144...
# 1   https://ldb-phinf.pstatic.net/20220413_244/164...
# 2   https://ldb-phinf.pstatic.net/20191225_95/1577...
# 3   https://ldb-phinf.pstatic.net/20150831_289/144...
# 4   https://ldb-phinf.pstatic.net/20201005_225/160...
# ..                                                ...
# ...

# %%
df = None 
for i,j in enumerate(json_list):
    if i != 0:
        tmp = df    
    df = pd.DataFrame(j[0]['data']['restaurants']['items'])
    
    if i != 0:
        df = pd.concat([tmp,df],ignore_index=True)

# %%
df
# Out:
#              id             name category hasBooking  \
# 0      13418405            우진해장국     향토음식       None
# 1    1000671392      랜디스도넛 제주애월점       도넛       None
# 2    1142108083               연돈      돈가스       None
# 3      11866447             올래국수       국수       None
# 4    1256246739             원앤온리       카페       None
# ..          ...              ...      ...        ...
# 295    13444885              대기정       한식       None
# 296  1221483187             제주마음       한식       None
# 297    71699464  월정리 해녀식당 구좌김녕본점       한식       True
# 298  1059446056              우영담     전복요리       None
# 299    11851700             만선식당      생선회       None
#
#                                               imageUrl          address  \
# 0    https://ldb-phinf.pstatic.net/20150901_132/144...         삼도이동 831
# 1    https://ldb-phinf.pstatic.net/20220413_244/164...         애월리 2471
# 2    https://ldb-phinf.pstatic.net/20191225_95/1577...       색달동 2156-2
# ...
