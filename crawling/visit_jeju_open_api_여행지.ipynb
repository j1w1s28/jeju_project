# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# c1 : 관광지 <br>
# c2 : 쇼핑 <br>
# c3: 숙박 <br>
# c4: 음식점 <br>
# c5: 축제/행사 <br>
# c6 : 테마여행<br>
# c7: 정보

# %%
url = 'http://api.visitjeju.net/vsjApi/contents/searchList'
params = {
    'apiKey':'ksxh0q4cwdbtc6urb',
    'locale':'kr',
    'category':'c4'
    
}

# %%
response =requests.get(url,params=params)
text=response.json()
text
# Out:
# {'result': '200',
#  'resultMessage': 'SUCCESS',
#  'totalCount': 1655,
#  'resultCount': 100,
#  'pageSize': 100,
#  'pageCount': 17,
#  'currentPage': 1,
#  'items': [{'alltag': '추자음식점,추자중식당,추자자장면,상추자식당,추자도,무료 WIFI,화장실,카드결제,현금결제,쉬움,가능',
#    'contentsid': 'CNTS_200000000009088',
#    'contentscd': {'value': 'c4', 'label': '음식점', 'refId': 'contentscd>c4'},
#    'title': '동해루',
#    'region1cd': {'value': 'region3',
#     'label': '섬 속의 섬',
#     'refId': 'region>region3'},
#    'region2cd': {'value': '32', 'label': '추차도', 'refId': 'region3>32'},
#    'address': '제주특별자치도 제주시 추자면 대서리 162',
#    'roadaddress': '제주특별자치도 제주시 추자면 추자로 58-1',
#    'tag': '추자음식점,추자중식당,추자자장면,상추자식당,추자도,음식,짜장면,짬뽕,탕수육,잡채밥,식당,중식',
#    'introduction': '추자에서 먹을 수 있는 중식전문점',
#    'latitude': 33.9642903,
#    'longitude': 126.2929862,
#    'postcode': None,
#    'phoneno': '064-742-3615',
#    'repPhoto': {'descseo': '동해루',
#     'photoid': {'photoid': 2019022560033,
# ...

# %%
text.get('items')[0]
# Out:
# {'alltag': '추자음식점,추자중식당,추자자장면,상추자식당,추자도,무료 WIFI,화장실,카드결제,현금결제,쉬움,가능',
#  'contentsid': 'CNTS_200000000009088',
#  'contentscd': {'value': 'c4', 'label': '음식점', 'refId': 'contentscd>c4'},
#  'title': '동해루',
#  'region1cd': {'value': 'region3',
#   'label': '섬 속의 섬',
#   'refId': 'region>region3'},
#  'region2cd': {'value': '32', 'label': '추차도', 'refId': 'region3>32'},
#  'address': '제주특별자치도 제주시 추자면 대서리 162',
#  'roadaddress': '제주특별자치도 제주시 추자면 추자로 58-1',
#  'tag': '추자음식점,추자중식당,추자자장면,상추자식당,추자도,음식,짜장면,짬뽕,탕수육,잡채밥,식당,중식',
#  'introduction': '추자에서 먹을 수 있는 중식전문점',
#  'latitude': 33.9642903,
#  'longitude': 126.2929862,
#  'postcode': None,
#  'phoneno': '064-742-3615',
#  'repPhoto': {'descseo': '동해루',
#   'photoid': {'photoid': 2019022560033,
#    'imgpath': 'https://api.cdn.visitjeju.net/photomng/imgpath/201908/20/5f8a9a45-47a2-4140-bcb1-e1ec015bdeb3.JPG',
#    'thumbnailpath': 'https://api.cdn.visitjeju.net/photomng/thumbnailpath/201908/20/0e401dab-6d04-4463-893b-33e499b34a5c.JPG'}}}

# %%
url = 'http://api.visitjeju.net/vsjApi/contents/searchList'
params = {
    'apiKey':'ksxh0q4cwdbtc6urb',
    'locale':'kr',
    'category':'c1',
    'cid':'CNTS_000000000021031'
}

# %%
response =requests.get(url,params=params)
text=response.json()
text
# Out:
# {'result': '200',
#  'resultMessage': 'SUCCESS',
#  'totalCount': 1,
#  'resultCount': 1,
#  'pageSize': 100,
#  'pageCount': 1,
#  'currentPage': 1,
#  'items': [{'alltag': '걷기/등산',
#    'contentsid': 'CNTS_000000000021031',
#    'contentscd': {'value': 'c1', 'label': '관광지', 'refId': 'contentscd>c1'},
#    'title': '추자연도교',
#    'region1cd': {'value': 'region3',
#     'label': '섬 속의 섬',
#     'refId': 'region>region3'},
#    'region2cd': {'value': '32', 'label': '추차도', 'refId': 'region3>32'},
#    'address': '제주특별자치도 제주시 추자면 영흥리 97-3',
#    'roadaddress': '제주특별자치도 제주시 추자면 영흥리 97-3',
#    'tag': '걷기/등산',
#    'introduction': '상추자도와 하추자도를 잇는 추자 연도교',
#    'latitude': 33.95409,
#    'longitude': 126.3023,
#    'postcode': None,
#    'phoneno': '--',
#    'repPhoto': {'descseo': '추자연도교',
#     'photoid': {'photoid': 10415,
#      'imgpath': 'https://api.cdn.visitjeju.net/photomng/imgpath/201804/30/f6eb13cd-e9bd-42a0-9f67-9704361f2e13.gif',
# ...
