# %%
import requests

# %% [markdown]
# ### 카테고리
# 관광지 : cate0000000002  마지막 페이지 : 92<br>
# 쇼핑 : cate0000000003 <br>
# 숙박 : cate0000000004 <br>
# 음식 : cate0000000005 <br>

# %%
p = {
    '_siteId': 'jejuavj',
    'locale': 'kr',
    'device': 'pc',
    #카테고리
    'cate1cd': 'cate0000000002',
    'tag': '',
    'sorting': 'reviewcnt+desc,+title_kr+asc',
    'region1cd': '',
    'region2cd': '',
    'pageSize': 1103
}
h = {
    'Cookie': 'iceJWT=SDP+eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJBbm9ueW1vdXMiLCJhdWQiOiI4MjlhMTI1OS0xOWI4LTQ1ZDItODA3Ni04YTBjMmYzOWZhZDAiLCJqdGkiOiI4MjlhMTI1OS0xOWI4LTQ1ZDItODA3Ni04YTBjMmYzOWZhZDAiLCJpc3MiOiJJLU9OIiwiaWF0IjoxNjU3NzYwNzM0LCJleHAiOjE2NTc4Njg3MzR9.zHVElYxu8hZp5Ic4CuUhyeDGPIPNE4D9SsM9wCVDYhJzIEULWlnlDRSVMpuwI0dx_CerniXrKF4s8yQOVp83pw; iceRefreshJWT=SDP+eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJBbm9ueW1vdXMiLCJhdWQiOiJiZDZkYjIyNC1lM2RjLTQ1ZGUtYmEwNy0wMWEwZjBhNGJjYmYiLCJpc3MiOiJJLU9OIiwianRpIjoiMzUxYzJmZTYtYjNmMC00ZWEzLWJiZDMtZGM3OWUyNWQyMjQzIiwiaWF0IjoxNjU3NzYwNzM0LCJleHAiOjQxMDI0MTI0MDB9.f_gz03Nf9_VAdDagVW14v7iE4scoUzFIoR9vDXw9gw_mx5PbLlwx_KAapFPyqvMG-0d5thwIU6qgbbbPlR9XeQ; Hm_lvt_f6d5e380b023c5b1e946de764e07a2a2=1657760733; _gid=GA1.2.1221448812.1657760733; _ga=GA1.1.520684781.1657760733; Hm_lpvt_f6d5e380b023c5b1e946de764e07a2a2=1657769443; _ga_WR7WEFWP2T=GS1.1.1657766236.2.1.1657770424.0'
}

# %%
#검색 카테고리 max페이지 수
maxPG = 92
#for i in range(1,maxPG+1):
res = requests.get('https://api.visitjeju.net/api/contents/list?page=1&', params=p, headers=h)
#pagelist.append(res.json())
res.json()
# Out:
# {'result': '200',
#  'resultMessage': 'SUCCESS',
#  'totalCount': 1103,
#  'resultCount': 1103,
#  'pageSize': 1103,
#  'pageCount': 1,
#  'currentPage': 1,
#  'items': [{'alltag': '휴식/힐링,체험관광,액티비티,사계절',
#    'contentsid': 'CNTS_200000000012469',
#    'contentscd': {'value': 'c1', 'label': '관광지', 'refId': 'contentscd>c1'},
#    'title': '제로스테이션(제로포인트트레일)',
#    'region1cd': {'value': 'region1',
#     'label': '제주시',
#     'refId': 'region>region1'},
#    'region2cd': {'value': '11', 'label': '제주시내', 'refId': 'region1>11'},
#    'address': '제주특별자치도 제주시 건입동 1136 2층',
#    'roadaddress': '제주특별자치도 제주시 산지로 25 2층',
#    'tag': '휴식/힐링,체험관광,액티비티,사계절,체험,레저/체험,어트랙션',
#    'introduction': '제로스테이션은 산지천에 위치한 카페이자 길과 여행을 사랑하는 사람들을 위한 공간이다. 이곳은 제로포인트트레일의 참여자를 위한 베이스캠프 역할을 하고 있다. 제로포인트트레일은 해발 0m인 제주 해안가에서 출발해 해발 1,947m인 한라산 정상까지 차량, 동력의 힘을 빌리지 않고 오로지 참가자의 두 발로 정상까지 오르는 트레킹 프로그램이다.',
#    'readcnt': 530,
#    'likecnt': 0,
#    'reviewcnt': 0,
#    'markcnt': 0,
#    'snssharecnt': 1,
# ...

# %% [markdown]
# ##### pagelist[0]

# %%
text= res.json()

# %%
items=text.get('items')

# %%
len(items)
# Out:
# 1103

# %%
items[0]
# Out:
# {'alltag': '휴식/힐링,체험관광,액티비티,사계절',
#  'contentsid': 'CNTS_200000000012469',
#  'contentscd': {'value': 'c1', 'label': '관광지', 'refId': 'contentscd>c1'},
#  'title': '제로스테이션(제로포인트트레일)',
#  'region1cd': {'value': 'region1', 'label': '제주시', 'refId': 'region>region1'},
#  'region2cd': {'value': '11', 'label': '제주시내', 'refId': 'region1>11'},
#  'address': '제주특별자치도 제주시 건입동 1136 2층',
#  'roadaddress': '제주특별자치도 제주시 산지로 25 2층',
#  'tag': '휴식/힐링,체험관광,액티비티,사계절,체험,레저/체험,어트랙션',
#  'introduction': '제로스테이션은 산지천에 위치한 카페이자 길과 여행을 사랑하는 사람들을 위한 공간이다. 이곳은 제로포인트트레일의 참여자를 위한 베이스캠프 역할을 하고 있다. 제로포인트트레일은 해발 0m인 제주 해안가에서 출발해 해발 1,947m인 한라산 정상까지 차량, 동력의 힘을 빌리지 않고 오로지 참가자의 두 발로 정상까지 오르는 트레킹 프로그램이다.',
#  'readcnt': 530,
#  'likecnt': 0,
#  'reviewcnt': 0,
#  'markcnt': 0,
#  'snssharecnt': 1,
#  'schedulecnt': 0,
#  'visitcnt': 0,
#  'evelpt': 0,
#  'latitude': 33.5147335,
#  'longitude': 126.5292798,
#  'postcode': None,
#  'phoneno': '064-702-1947',
# ...

# %%
import pandas as pd

# %%
tour_places =pd.DataFrame(items)

# %%
tour_places.to_csv('../data/제주도관광지.csv',encoding='utf-8')

# %%
tour_places
# Out:
#                                                  alltag            contentsid  \
# 0                                   휴식/힐링,체험관광,액티비티,사계절  CNTS_200000000012469
# 1     부모,커플,친구,경관/포토,휴식/힐링,테마공원,오름,사계절,청년,중/장년,휴식/치유...  CNTS_200000000009501
# 2     커플,부모,혼자,친구,아이,맑음,흐림,비.눈,경관/포토,휴식/힐링,미술/박물관,사계...  CNTS_200000000012075
# 3                                                   관광지  CNTS_200000000013590
# 4                  실내,문화유적지,가을,문화관광,역사유적,어트랙션,공용주차장,어려움  CNTS_000000000021292
# ...                                                 ...                   ...
# 1098  해변,경관/포토,커플,맑음,여름,공용주차장,화장실,음료대,유도 및 안내시설,경보 및...  CONT_000000000500682
# 1099                         커플,친구,아이,부모,혼자,경관/포토,여름,맑음  CNTS_000000000018385
# 1100                                       체험관광,아이,맑음,봄  CNTS_000000000020230
# 1101  승마,액티비티,친구,커플,공용주차장,현금결제,카드결제,화장실,무료 WIFI,음료대,...  CONT_000000000500560
# 1102  섬속의섬,일몰,휴식/힐링,아이,맑음,여름,공용주차장,현금결제,카드결제,화장실,편의점...  CONT_000000000500267
#
# ...
